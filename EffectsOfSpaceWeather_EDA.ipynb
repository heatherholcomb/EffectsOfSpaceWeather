# %% [markdown]
# # Effects of Space Weather
#
# ### MSDS 696 Practicum II
# #### Regis University
# #### Heather Holcomb
#
# ### Description:
# ###### Space Weather describes the variations in the space environment between the sun and earth. In particular, Space Weather describes the phenomena that impact systems and technologies in orbit and on Earth. Space Weather can occur anywhere from the surface of the sun to the surface of the earth.
# ###### Different aspects of space weather can effect multiple systems here on earth such as GPS, Climate, Radio and Satellite Communication. Solar flares can affect radio waves, solar energetic particles can cause electrical failure in satellites and block radio communications, geomagnetic storms can modify systems from GPS, when cosmic rays are high it can create nucleation in the atmosphere and produce more cloudy conditions and solar irradiance can have an affect on climate as well.
# ###### The questions i would like to answer with this project include:
# ###### - How does the Kp index, or geomagnetic activity effect climate?
# ###### - How does the F10.7 index effect climate?
# ###### - How does the Ap - Planetary Equivalent Amplitude effect climate?
# ###### - How does Cp - Planetary Daily Character Figure effect climate?
# ###### - How does ISN - International Sunspot Number effect climate?
# ###### - Can i predict space weather using historical data?

# %%
# Load necessary libraries 
import re
import pandas as pd
import os
import matplotlib.pyplot as plt
import netCDF4
import seaborn as sns
import numpy as np 
import statsmodels.formula.api as smf
import statsmodels.api
import fbprophet
import random

from netCDF4 import Dataset
from scipy import stats
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn import linear_model
# Out:
# Importing plotly failed. Interactive plots will not work.

# %% [markdown]
# # Space Weather Data - Exploratory Data Analysis

# %%
dfSpaceWeather = pd.read_csv('Data\SpaceWeatherData_Cleaned', header = 0, delimiter=r"\s+")

# %%
dfSpaceWeather.columns
# Out:
# Index(['yy', 'mm', 'dd', 'BSRN', 'ND', 'Kp', 'Kp.1', 'Kp.2', 'Kp.3', 'Kp.4',
#        'Kp.5', 'Kp.6', 'Kp.7', 'Sum', 'Ap', 'Ap.1', 'Ap.2', 'Ap.3', 'Ap.4',
#        'Ap.5', 'Ap.6', 'Ap.7', 'Avg', 'Cp', 'C9', 'ISN', 'F10.7', 'Q', 'Ctr81',
#        'Lst81', 'F10.7.1', 'Ctr81.1', 'Lst81.1'],
#       dtype='object')

# %%
#Rename columns to make sense 
dfSpaceWeather = dfSpaceWeather.rename(columns={
    "yy": "Year", 
    "mm": "Month", 
    "dd": "Day", 
    "BSRN": "BartelsSolarRotationNumber", 
    "ND": "NumberofDaywithintheBartels", 
    "Kp": "Kp_0000_0300", 
    "Kp.1": "Kp_0300_0600", 
    "Kp.2": "Kp_0600_0900", 
    "Kp.3": "Kp_0900_1200", 
    "Kp.4": "Kp_1200_1500",
    "Kp.5": "Kp_1500_1800",
    "Kp.6": "Kp_1800_2100",
    "Kp.7": "Kp_2100_0000",
    "Sum": "SumOfKps", 
    "Ap": "PlanetaryEquivalentAmplitude_0000_0300",
    "Ap.1": "PlanetaryEquivalentAmplitude_0300_0600",
    "Ap.2": "PlanetaryEquivalentAmplitude_0600_0900",
    "Ap.3": "PlanetaryEquivalentAmplitude_0900_1200",
    "Ap.4": "PlanetaryEquivalentAmplitude_1200_1500",
    "Ap.5": "PlanetaryEquivalentAmplitude_1500_1800",
    "Ap.6": "PlanetaryEquivalentAmplitude_1800_2100",
    "Ap.7": "PlanetaryEquivalentAmplitude_2100_0000",
    "Avg": "ArithmeticAverageof8Ap",
    "Cp": "PlanetaryDailyCharacterFigure", 
    "C9": "CpConversion", 
    "ISN": "InternationalSunspotNumber",
    "F10.7": "F10_7",
    "Q": "FluxQualifier",
    "Ctr81": "Centered81_dayArithmeticAverageofF10_7",
    "Lst81": "Last81DayArithmeticAverageofF10_7", 
    "F10.7.1": "ObservedValueOfF10_7",
    "Ctr81.1": "Centered81DayArithmeticAverageOfF10_7",
    "Lst81.1": "Last81DayArithmeticAverageOfF10_7"})

# %%
dfSpaceWeather.columns
# Out:
# Index(['Year', 'Month', 'Day', 'BartelsSolarRotationNumber',
#        'NumberofDaywithintheBartels', 'Kp_0000_0300', 'Kp_0300_0600',
#        'Kp_0600_0900', 'Kp_0900_1200', 'Kp_1200_1500', 'Kp_1500_1800',
#        'Kp_1800_2100', 'Kp_2100_0000', 'SumOfKps',
#        'PlanetaryEquivalentAmplitude_0000_0300',
#        'PlanetaryEquivalentAmplitude_0300_0600',
#        'PlanetaryEquivalentAmplitude_0600_0900',
#        'PlanetaryEquivalentAmplitude_0900_1200',
#        'PlanetaryEquivalentAmplitude_1200_1500',
#        'PlanetaryEquivalentAmplitude_1500_1800',
#        'PlanetaryEquivalentAmplitude_1800_2100',
#        'PlanetaryEquivalentAmplitude_2100_0000', 'ArithmeticAverageof8Ap',
#        'PlanetaryDailyCharacterFigure', 'CpConversion',
#        'InternationalSunspotNumber', 'F10_7', 'FluxQualifier',
#        'Centered81_dayArithmeticAverageofF10_7',
#        'Last81DayArithmeticAverageofF10_7', 'ObservedValueOfF10_7',
#        'Centered81DayArithmeticAverageOfF10_7',
#        'Last81DayArithmeticAverageOfF10_7'],
#       dtype='object')

# %%
def myPlot(x,y):
    x = x
    y = y
    fig_size = plt.rcParams["figure.figsize"]
    fig_size[0] = 15
    plt.rcParams["figure.figsize"] = fig_size
    plt.plot(x,y, color = 'green', linestyle='dashed', linewidth=3, marker='x', markerfacecolor = 'blue', markersize=10)

# %%
is_1957 = dfSpaceWeather['Year']==1957
df_1957 = dfSpaceWeather[is_1957]
is_Oct = df_1957['Month']==10
df_Oct1957 = df_1957[is_Oct]
df_Oct1957
# Out:
#     Year  Month  Day  BartelsSolarRotationNumber  NumberofDaywithintheBartels  \
# 0   1957     10    1                        1700                           19
# 1   1957     10    2                        1700                           20
# 2   1957     10    3                        1700                           21
# 3   1957     10    4                        1700                           22
# 4   1957     10    5                        1700                           23
# 5   1957     10    6                        1700                           24
# 6   1957     10    7                        1700                           25
# 7   1957     10    8                        1700                           26
# 8   1957     10    9                        1700                           27
# 9   1957     10   10                        1701                            1
# 10  1957     10   11                        1701                            2
# 11  1957     10   12                        1701                            3
# 12  1957     10   13                        1701                            4
# 13  1957     10   14                        1701                            5
# 14  1957     10   15                        1701                            6
# 15  1957     10   16                        1701                            7
# 16  1957     10   17                        1701                            8
# 17  1957     10   18                        1701                            9
# 18  1957     10   19                        1701                           10
# 19  1957     10   20                        1701                           11
# 20  1957     10   21                        1701                           12
# 21  1957     10   22                        1701                           13
# 22  1957     10   23                        1701                           14
# 23  1957     10   24                        1701                           15
# 24  1957     10   25                        1701                           16
# 25  1957     10   26                        1701                           17
# 26  1957     10   27                        1701                           18
# 27  1957     10   28                        1701                           19
# 28  1957     10   29                        1701                           20
# 29  1957     10   30                        1701                           21
# 30  1957     10   31                        1701                           22
#
#     Kp_0000_0300  Kp_0300_0600  Kp_0600_0900  Kp_0900_1200  Kp_1200_1500  ...  \
# 0             43            40            30            20            37  ...
# 1             37            37            17            17            27  ...
# 2             27            20            13            33            37  ...
# 3             30            30            23            27            23  ...
# 4             30            30            17            23            20  ...
# 5             17             3            10             7             0  ...
# 6             10            20            17            17            17  ...
# 7             17             0            10             7             3  ...
# 8              3            17            23            17            23  ...
# 9             30            40            40            30            23  ...
# 10            33            43            33            43            37  ...
# 11            23            30            27            37            27  ...
# 12            50            53            30            23            27  ...
# 13            43            63            57            50            43  ...
# 14            33            20            17            23            30  ...
# 15            13             3             3             7            13  ...
# 16            13            13            13            30            27  ...
# 17            17            13            17            13             7  ...
# 18             7            13            27            33            17  ...
# 19            20            23            13            20            20  ...
# 20            33            27            27            17            27  ...
# 21            43            30            37            37            23  ...
# 22            50            27            37            30            13  ...
# 23            20            17            20            23            27  ...
# 24            20            17            20            30            20  ...
# 25            30            20            13            23            20  ...
# 26            20            20            20            27            40  ...
# 27            40            20            33            33            20  ...
# 28            37            30            37            30            33  ...
# 29            30            37            47            30            27  ...
# 30            10            13            17            20            37  ...
#
#     PlanetaryDailyCharacterFigure  CpConversion  InternationalSunspotNumber  \
# 0                             1.1           5.0                       236.0
# 1                             0.7           3.0                       234.0
# 2                             1.0           5.0                       242.0
# 3                             0.7           3.0                       217.0
# 4                             0.6           3.0                       219.0
# 5                             0.0           0.0                       227.0
# 6                             0.2           1.0                       234.0
# 7                             0.0           0.0                       244.0
# 8                             0.4           2.0                       267.0
# 9                             1.0           5.0                       264.0
# 10                            1.0           5.0                       232.0
# 11                            0.8           4.0                       236.0
# 12                            1.2           6.0                       244.0
# 13                            1.6           7.0                       232.0
# 14                            0.7           3.0                       264.0
# 15                            0.1           0.0                       268.0
# 16                            0.4           2.0                       251.0
# 17                            0.3           1.0                       222.0
# 18                            0.5           2.0                       217.0
# 19                            0.6           3.0                       230.0
# 20                            1.2           6.0                       237.0
# 21                            1.0           5.0                       241.0
# 22                            1.0           5.0                       254.0
# 23                            0.5           2.0                       276.0
# 24                            0.4           2.0                       240.0
# 25                            0.4           2.0                       293.0
# 26                            0.7           3.0                       280.0
# 27                            0.8           4.0                       317.0
# 28                            1.0           5.0                       334.0
# 29                            0.9           4.0                       317.0
# 30                            0.4           2.0                       299.0
#
#     F10_7  FluxQualifier  Centered81_dayArithmeticAverageofF10_7  \
# 0   268.0            0.0                                   265.2
# 1   252.0            0.0                                   266.0
# 2   265.0            0.0                                   266.7
# 3   237.0            0.0                                   267.4
# 4   245.0            0.0                                   267.8
# 5   250.0            0.0                                   268.1
# 6   253.0            0.0                                   268.4
# 7   261.0            0.0                                   268.2
# 8   275.0            0.0                                   268.3
# 9   275.0            0.0                                   268.2
# 10  278.0            0.0                                   267.8
# 11  284.0            0.0                                   267.8
# 12  281.0            0.0                                   268.1
# 13  289.0            0.0                                   268.2
# 14  277.0            0.0                                   268.7
# 15  289.0            0.0                                   269.1
# 16  272.0            0.0                                   269.5
# 17  294.0            0.0                                   270.0
# 18  291.0            0.0                                   270.3
# 19  303.0            0.0                                   270.5
# 20  282.0            0.0                                   270.9
# 21  274.0            0.0                                   271.2
# 22  295.0            0.0                                   271.1
# 23  280.0            0.0                                   271.3
# 24  259.0            0.0                                   271.6
# 25  266.0            0.0                                   271.8
# 26  296.0            0.0                                   271.9
# 27  323.0            0.0                                   271.4
# 28  342.0            0.0                                   271.0
# 29  344.0            0.0                                   270.1
# 30  318.0            0.0                                   269.0
#
#     Last81DayArithmeticAverageofF10_7  ObservedValueOfF10_7  \
# 0                               230.6                 269.3
# 1                               231.4                 253.3
# 2                               232.3                 266.3
# 3                               232.9                 238.2
# 4                               233.5                 246.2
# 5                               233.9                 251.2
# 6                               234.2                 254.3
# 7                               234.7                 262.6
# 8                               235.2                 276.6
# 9                               235.6                 276.6
# 10                              236.1                 279.7
# 11                              236.6                 285.7
# 12                              236.9                 282.7
# 13                              237.4                 290.7
# 14                              238.0                 278.9
# 15                              238.7                 291.0
# 16                              239.4                 273.9
# 17                              240.6                 296.1
# 18                              241.8                 293.0
# 19                              243.2                 305.1
# 20                              244.1                 284.0
# 21                              245.1                 276.2
# 22                              246.3                 297.4
# 23                              247.3                 282.2
# 24                              248.2                 261.1
# 25                              249.2                 268.1
# 26                              250.6                 298.4
# 27                              252.3                 325.6
# 28                              254.4                 344.7
# 29                              256.5                 346.8
# 30                              258.3                 320.5
#
#     Centered81DayArithmeticAverageOfF10_7  Last81DayArithmeticAverageOfF10_7
# 0                                   266.6                              230.9
# 1                                   267.4                              231.7
# 2                                   268.1                              232.7
# 3                                   268.8                              233.3
# 4                                   269.3                              233.9
# 5                                   269.6                              234.3
# 6                                   269.9                              234.6
# 7                                   269.8                              235.2
# 8                                   270.0                              235.7
# 9                                   269.8                              236.1
# 10                                  269.5                              236.7
# 11                                  269.5                              237.1
# 12                                  269.9                              237.5
# 13                                  270.0                              238.0
# 14                                  270.5                              238.6
# 15                                  271.0                              239.3
# 16                                  271.5                              240.1
# 17                                  271.9                              241.3
# 18                                  272.3                              242.5
# 19                                  272.5                              243.9
# 20                                  273.0                              244.9
# 21                                  273.4                              245.9
# 22                                  273.3                              247.1
# 23                                  273.6                              248.2
# 24                                  273.8                              249.1
# 25                                  274.1                              250.1
# 26                                  274.2                              251.5
# 27                                  273.8                              253.3
# 28                                  273.5                              255.4
# 29                                  272.6                              257.6
# 30                                  271.5                              259.4
#
# [31 rows x 33 columns]

# %%
x = df_Oct1957.Day
y = df_Oct1957.SumOfKps
myPlot(x,y)

# %%
is_Nov = df_1957['Month']==11
df_Nov1957 = df_1957[is_Nov]
df_Nov1957
x_Nov1957 = df_Nov1957.Day
y_Nov1957 = df_Nov1957.SumOfKps
myPlot(x_Nov1957, y_Nov1957)

# %%
dfSpaceWeather.Year.unique()
# Out:
# array([1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#        1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#        1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], dtype=int64)

# %%
#Create a new dataFrame for Space Weather
#Do average values for each month
dfSpaceWeatherAverage = dfSpaceWeather.groupby(['Year', 'Month'])['SumOfKps', 'ArithmeticAverageof8Ap', 'PlanetaryDailyCharacterFigure'].mean()
dfSpaceWeatherAverage
# Out:
# c:\users\heath\.conda\envs\opencv\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#               SumOfKps  ArithmeticAverageof8Ap  PlanetaryDailyCharacterFigure
# Year Month
# 1957 10     198.612903               13.774194                       0.683871
#      11     223.766667               18.033333                       0.810000
#      12     232.483871               17.741935                       0.841935
# 1958 1      208.387097               14.741935                       0.738710
#      2      265.642857               26.857143                       0.978571
# ...                ...                     ...                            ...
# 2019 11      79.333333                4.200000                       0.156667
#      12      67.419355                3.064516                       1.870968
# 2020 1       98.709677                4.806452                       5.935484
#      2      126.206897                6.413793                       0.379310
#      3      107.636364                4.818182                      15.181818
#
# [750 rows x 3 columns]

# %%
spaceWeather_dict = dfSpaceWeather.groupby(['Year','Month']).agg({
    'SumOfKps': 'mean',
    'ArithmeticAverageof8Ap': 'mean',
    'PlanetaryDailyCharacterFigure': 'mean',
    'NumberofDaywithintheBartels' : 'mean',
    'PlanetaryDailyCharacterFigure' : 'mean',
    'CpConversion' : 'mean',
    'InternationalSunspotNumber' : 'mean',
    'F10_7' : 'mean',
    'FluxQualifier' : 'mean',
    'Centered81_dayArithmeticAverageofF10_7' : 'mean',
    'Last81DayArithmeticAverageofF10_7' : 'mean',
    'ObservedValueOfF10_7' : 'mean',
    'Centered81DayArithmeticAverageOfF10_7' : 'mean',
    'Last81DayArithmeticAverageOfF10_7' : 'mean'
})
spaceWeather_dict
# Out:
#               SumOfKps  ArithmeticAverageof8Ap  PlanetaryDailyCharacterFigure  \
# Year Month
# 1957 10     198.612903               13.774194                       0.683871
#      11     223.766667               18.033333                       0.810000
#      12     232.483871               17.741935                       0.841935
# 1958 1      208.387097               14.741935                       0.738710
#      2      265.642857               26.857143                       0.978571
# ...                ...                     ...                            ...
# 2019 11      79.333333                4.200000                       0.156667
#      12      67.419355                3.064516                       1.870968
# 2020 1       98.709677                4.806452                       5.935484
#      2      126.206897                6.413793                       0.379310
#      3      107.636364                4.818182                      15.181818
#
#             NumberofDaywithintheBartels  CpConversion  \
# Year Month
# 1957 10                       14.838710      3.225806
#      11                       15.000000      3.700000
#      12                       14.000000      3.903226
# 1958 1                        12.774194      3.354839
#      2                        13.750000      4.500000
# ...                                 ...           ...
# 2019 11                       14.200000      0.566667
#      12                       14.709677     70.967742
# 2020 1                        15.225806     72.322581
#      2                        14.862069     71.034483
#      3                         6.000000     57.181818
#
#             InternationalSunspotNumber       F10_7  FluxQualifier  \
# Year Month
# 1957 10                     253.806452  281.225806       0.000000
#      11                     210.866667  256.100000       0.000000
#      12                     239.419355  284.322581       0.129032
# 1958 1                      202.451613  247.870968       0.000000
#      2                      164.928571  209.857143       0.142857
# ...                                ...         ...            ...
# 2019 11                       0.500000   68.663333       0.000000
#      12                       0.000000   70.593548      68.380645
# 2020 1                        0.000000   71.490323      70.090323
#      2                        0.000000   71.275862      71.362069
#      3                       12.909091   71.163636      71.581818
#
#             Centered81_dayArithmeticAverageofF10_7  \
# Year Month
# 1957 10                                 269.212903
#      11                                 270.756667
#      12                                 268.045161
# 1958 1                                  251.338710
#      2                                  233.932143
# ...                                            ...
# 2019 11                                  68.796667
#      12                                  73.248387
# 2020 1                                   74.709677
#      2                                   72.800000
#      3                                   71.172727
#
#             Last81DayArithmeticAverageofF10_7  ObservedValueOfF10_7  \
# Year Month
# 1957 10                            241.138710            283.109677
#      11                            266.740000            259.216667
#      12                            269.800000            289.358065
# 1958 1                             271.277419            251.506452
#      2                             257.303571            211.796429
# ...                                       ...                   ...
# 2019 11                             68.026667             70.183333
#      12                             72.683871             69.506452
# 2020 1                              73.658065             72.035484
#      2                              72.906897             73.586207
#      3                              72.409091             73.577778
#
#             Centered81DayArithmeticAverageOfF10_7  \
# Year Month
# 1957 10                                271.119355
#      11                                274.023333
#      12                                272.129032
# 1958 1                                 254.929032
#      2                                 236.132143
# ...                                           ...
# 2019 11                                 70.223333
#      12                                       NaN
# 2020 1                                        NaN
#      2                                        NaN
#      3                                        NaN
#
#             Last81DayArithmeticAverageOfF10_7
# Year Month
# 1957 10                            241.803226
#      11                            268.293333
#      12                            272.619355
# 1958 1                             275.267742
#      2                             261.185714
# ...                                       ...
# 2019 11                             68.073333
#      12                                   NaN
# 2020 1                                    NaN
#      2                                    NaN
#      3                                    NaN
#
# [750 rows x 13 columns]

# %%
dfSpaceWeatherAverage = pd.DataFrame(spaceWeather_dict)

# %% [markdown]
# # Climate Data - Exploratory Data Analysis

# %%
dfClimate = pd.read_csv('Data\Weather\MonthlyClimate.csv', header = 0, delimiter=r",")

# %%
dfClimate.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'AWND',
#        'AWND_ATTRIBUTES', 'CDSD', 'CDSD_ATTRIBUTES', 'CLDD', 'CLDD_ATTRIBUTES',
#        'DP01', 'DP01_ATTRIBUTES', 'DP10', 'DP10_ATTRIBUTES', 'DT00',
#        'DT00_ATTRIBUTES', 'DT32', 'DT32_ATTRIBUTES', 'DX32', 'DX32_ATTRIBUTES',
#        'DX70', 'DX70_ATTRIBUTES', 'DX90', 'DX90_ATTRIBUTES', 'EMNT',
#        'EMNT_ATTRIBUTES', 'EMXP', 'EMXP_ATTRIBUTES', 'EMXT', 'EMXT_ATTRIBUTES',
#        'HDSD', 'HDSD_ATTRIBUTES', 'HTDD', 'HTDD_ATTRIBUTES', 'PRCP',
#        'PRCP_ATTRIBUTES', 'SNOW', 'SNOW_ATTRIBUTES', 'TAVG', 'TAVG_ATTRIBUTES',
#        'TMAX', 'TMAX_ATTRIBUTES', 'TMIN', 'TMIN_ATTRIBUTES', 'TSUN',
#        'TSUN_ATTRIBUTES', 'WDF2', 'WDF2_ATTRIBUTES', 'WDF5', 'WDF5_ATTRIBUTES',
#        'WSF2', 'WSF2_ATTRIBUTES', 'WSF5', 'WSF5_ATTRIBUTES'],
#       dtype='object')

# %%
#Rename columns to make sense 
dfClimate = dfClimate.rename(columns={
    "EMXP": "ExtremeMaxPrecip",
    "EMXT": "ExtremeMaxTemp",
    "PRCP": "Precipitation",
    "DX90": "DaysMaxTempGT90F",
    "DP10": "DaysMoreThan1InchRain",
    "DX70": "DaysMaxTempGT70F",
    "EMNT": "ExtremeMinTemp",
    "DT32": "DaysMinTempLT32F",
    "WDF2": "DirFast2MinWind",
    "DX32": "DaysMaxTempLT32F",
    "WDF5": "DirFast5MinWind",
    "TMAX": "MaxTemp",
    "WSF2": "SpeedFast2MinWind",
    "WSF5": "SpeedFast5MinWind",
    "SNOW": "Snowfall",
    "HDSD": "HeatDegDaysSeasonToDate",
    "HTDD": "HeatDegDays",
    "DP01": "DaysWithGTTenthInchPrecip",
    "CDSD": "CoolDegDaysSeasonToDate",
    "DT00": "DaysMinTempLT0F",
    "AWND": "AverageWindSpeed",
    "CLDD": "CoolDegDays",
    "TAVG": "AverageTemp",
    "TMIN": "MinTemp",
    "TSUN": "TotalSunshinePeriod"})

# %%
dfClimate.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE',
#        'AverageWindSpeed', 'AWND_ATTRIBUTES', 'CoolDegDaysSeasonToDate',
#        'CDSD_ATTRIBUTES', 'CoolDegDays', 'CLDD_ATTRIBUTES',
#        'DaysWithGTTenthInchPrecip', 'DP01_ATTRIBUTES', 'DaysMoreThan1InchRain',
#        'DP10_ATTRIBUTES', 'DaysMinTempLT0F', 'DT00_ATTRIBUTES',
#        'DaysMinTempLT32F', 'DT32_ATTRIBUTES', 'DaysMaxTempLT32F',
#        'DX32_ATTRIBUTES', 'DaysMaxTempGT70F', 'DX70_ATTRIBUTES',
#        'DaysMaxTempGT90F', 'DX90_ATTRIBUTES', 'ExtremeMinTemp',
#        'EMNT_ATTRIBUTES', 'ExtremeMaxPrecip', 'EMXP_ATTRIBUTES',
#        'ExtremeMaxTemp', 'EMXT_ATTRIBUTES', 'HeatDegDaysSeasonToDate',
#        'HDSD_ATTRIBUTES', 'HeatDegDays', 'HTDD_ATTRIBUTES', 'Precipitation',
#        'PRCP_ATTRIBUTES', 'Snowfall', 'SNOW_ATTRIBUTES', 'AverageTemp',
#        'TAVG_ATTRIBUTES', 'MaxTemp', 'TMAX_ATTRIBUTES', 'MinTemp',
#        'TMIN_ATTRIBUTES', 'TotalSunshinePeriod', 'TSUN_ATTRIBUTES',
#        'DirFast2MinWind', 'WDF2_ATTRIBUTES', 'DirFast5MinWind',
#        'WDF5_ATTRIBUTES', 'SpeedFast2MinWind', 'WSF2_ATTRIBUTES',
#        'SpeedFast5MinWind', 'WSF5_ATTRIBUTES'],
#       dtype='object')

# %%
dfClimate.NAME.unique()
# Out:
# array(['LONDON CORBIN AIRPORT, KY US', 'JEROME CO AIRPORT, ID US',
#        'SALINA MUNICIPAL AIRPORT, KS US',
#        'GREENVILLE MAINE FORESTRY SERVICE, ME US', 'ANNAPOLIS NAF, MD US'],
#       dtype=object)

# %%
dfClimate
# Out:
#           STATION                          NAME  LATITUDE  LONGITUDE  \
# 0     USW00003849  LONDON CORBIN AIRPORT, KY US  37.08722  -84.07694
# 1     USW00003849  LONDON CORBIN AIRPORT, KY US  37.08722  -84.07694
# 2     USW00003849  LONDON CORBIN AIRPORT, KY US  37.08722  -84.07694
# 3     USW00003849  LONDON CORBIN AIRPORT, KY US  37.08722  -84.07694
# 4     USW00003849  LONDON CORBIN AIRPORT, KY US  37.08722  -84.07694
# ...           ...                           ...       ...        ...
# 1099  USW00013752          ANNAPOLIS NAF, MD US  38.99130  -76.48910
# 1100  USW00013752          ANNAPOLIS NAF, MD US  38.99130  -76.48910
# 1101  USW00013752          ANNAPOLIS NAF, MD US  38.99130  -76.48910
# 1102  USW00013752          ANNAPOLIS NAF, MD US  38.99130  -76.48910
# 1103  USW00013752          ANNAPOLIS NAF, MD US  38.99130  -76.48910
#
#       ELEVATION     DATE  AverageWindSpeed AWND_ATTRIBUTES  \
# 0         362.1  2000-01               6.7              ,X
# 1         362.1  2000-02               6.3              ,X
# 2         362.1  2000-03               5.8              ,X
# 3         362.1  2000-04               6.3              ,X
# 4         362.1  2000-05               5.6              ,X
# ...         ...      ...               ...             ...
# 1099        1.8  2019-08               5.8             2,W
# 1100        1.8  2019-09               6.5             1,W
# 1101        1.8  2019-10               7.6              ,W
# 1102        1.8  2019-11               6.9             2,W
# 1103        1.8  2019-12               5.6              ,W
#
#       CoolDegDaysSeasonToDate CDSD_ATTRIBUTES  ...  TotalSunshinePeriod  \
# 0                         0.0               0  ...                  NaN
# 1                         0.0               0  ...                  NaN
# 2                         4.0               0  ...                  NaN
# 3                         4.0               0  ...                  NaN
# 4                       103.0               0  ...                  NaN
# ...                       ...             ...  ...                  ...
# 1099                      NaN             NaN  ...                  NaN
# 1100                      NaN             NaN  ...                  NaN
# 1101                      NaN             NaN  ...                  NaN
# 1102                      NaN             NaN  ...                  NaN
# 1103                      NaN             NaN  ...                  NaN
#
#      TSUN_ATTRIBUTES  DirFast2MinWind WDF2_ATTRIBUTES  DirFast5MinWind  \
# 0                NaN            250.0              ,X            190.0
# 1                NaN            260.0              ,X            230.0
# 2                NaN            260.0              ,X            260.0
# 3                NaN            280.0              ,X            270.0
# 4                NaN            260.0              ,X            270.0
# ...              ...              ...             ...              ...
# 1099             NaN            350.0              ,W            360.0
# 1100             NaN             10.0             1,W             10.0
# 1101             NaN            300.0              ,W            280.0
# 1102             NaN            340.0             2,W            340.0
# 1103             NaN            330.0              ,W            280.0
#
#      WDF5_ATTRIBUTES  SpeedFast2MinWind WSF2_ATTRIBUTES  SpeedFast5MinWind  \
# 0                 ,X               30.0              ,X               43.0
# 1                 ,X               29.1              ,X               40.0
# 2                 ,X               32.0              ,X               40.0
# 3                 ,X               38.0              ,X               52.0
# 4                 ,X               32.0              ,X               39.0
# ...              ...                ...             ...                ...
# 1099              ,W               25.9              ,W               39.0
# 1100             1,W               23.0             1,W               29.0
# 1101              ,W               29.1              ,W               49.0
# 1102             2,W               30.0             2,W               44.0
# 1103              ,W               25.9              ,W               39.0
#
#      WSF5_ATTRIBUTES
# 0                 ,X
# 1                 ,X
# 2                 ,X
# 3                 ,X
# 4                 ,X
# ...              ...
# 1099              ,W
# 1100             1,W
# 1101              ,W
# 1102             2,W
# 1103              ,W
#
# [1104 rows x 56 columns]

# %%
dfClimate_StationIndex = dfClimate.set_index('STATION')
dfClimate_StationIndex
# Out:
#                                      NAME  LATITUDE  LONGITUDE  ELEVATION  \
# STATION
# USW00003849  LONDON CORBIN AIRPORT, KY US  37.08722  -84.07694      362.1
# USW00003849  LONDON CORBIN AIRPORT, KY US  37.08722  -84.07694      362.1
# USW00003849  LONDON CORBIN AIRPORT, KY US  37.08722  -84.07694      362.1
# USW00003849  LONDON CORBIN AIRPORT, KY US  37.08722  -84.07694      362.1
# USW00003849  LONDON CORBIN AIRPORT, KY US  37.08722  -84.07694      362.1
# ...                                   ...       ...        ...        ...
# USW00013752          ANNAPOLIS NAF, MD US  38.99130  -76.48910        1.8
# USW00013752          ANNAPOLIS NAF, MD US  38.99130  -76.48910        1.8
# USW00013752          ANNAPOLIS NAF, MD US  38.99130  -76.48910        1.8
# USW00013752          ANNAPOLIS NAF, MD US  38.99130  -76.48910        1.8
# USW00013752          ANNAPOLIS NAF, MD US  38.99130  -76.48910        1.8
#
#                 DATE  AverageWindSpeed AWND_ATTRIBUTES  \
# STATION
# USW00003849  2000-01               6.7              ,X
# USW00003849  2000-02               6.3              ,X
# USW00003849  2000-03               5.8              ,X
# USW00003849  2000-04               6.3              ,X
# USW00003849  2000-05               5.6              ,X
# ...              ...               ...             ...
# USW00013752  2019-08               5.8             2,W
# USW00013752  2019-09               6.5             1,W
# USW00013752  2019-10               7.6              ,W
# USW00013752  2019-11               6.9             2,W
# USW00013752  2019-12               5.6              ,W
#
#              CoolDegDaysSeasonToDate CDSD_ATTRIBUTES  CoolDegDays  ...  \
# STATION                                                            ...
# USW00003849                      0.0               0          0.0  ...
# USW00003849                      0.0               0          0.0  ...
# USW00003849                      4.0               0          4.0  ...
# USW00003849                      4.0               0          0.0  ...
# USW00003849                    103.0               0         98.0  ...
# ...                              ...             ...          ...  ...
# USW00013752                      NaN             NaN        456.0  ...
# USW00013752                      NaN             NaN        322.0  ...
# USW00013752                      NaN             NaN         51.0  ...
# USW00013752                      NaN             NaN          0.0  ...
# USW00013752                      NaN             NaN          0.0  ...
#
#             TotalSunshinePeriod  TSUN_ATTRIBUTES DirFast2MinWind  \
# STATION
# USW00003849                 NaN              NaN           250.0
# USW00003849                 NaN              NaN           260.0
# USW00003849                 NaN              NaN           260.0
# USW00003849                 NaN              NaN           280.0
# USW00003849                 NaN              NaN           260.0
# ...                         ...              ...             ...
# USW00013752                 NaN              NaN           350.0
# USW00013752                 NaN              NaN            10.0
# USW00013752                 NaN              NaN           300.0
# USW00013752                 NaN              NaN           340.0
# USW00013752                 NaN              NaN           330.0
#
#              WDF2_ATTRIBUTES DirFast5MinWind  WDF5_ATTRIBUTES  \
# STATION
# USW00003849               ,X           190.0               ,X
# USW00003849               ,X           230.0               ,X
# USW00003849               ,X           260.0               ,X
# USW00003849               ,X           270.0               ,X
# USW00003849               ,X           270.0               ,X
# ...                      ...             ...              ...
# USW00013752               ,W           360.0               ,W
# USW00013752              1,W            10.0              1,W
# USW00013752               ,W           280.0               ,W
# USW00013752              2,W           340.0              2,W
# USW00013752               ,W           280.0               ,W
#
#             SpeedFast2MinWind  WSF2_ATTRIBUTES SpeedFast5MinWind  \
# STATION
# USW00003849              30.0               ,X              43.0
# USW00003849              29.1               ,X              40.0
# USW00003849              32.0               ,X              40.0
# USW00003849              38.0               ,X              52.0
# USW00003849              32.0               ,X              39.0
# ...                       ...              ...               ...
# USW00013752              25.9               ,W              39.0
# USW00013752              23.0              1,W              29.0
# USW00013752              29.1               ,W              49.0
# USW00013752              30.0              2,W              44.0
# USW00013752              25.9               ,W              39.0
#
#              WSF5_ATTRIBUTES
# STATION
# USW00003849               ,X
# USW00003849               ,X
# USW00003849               ,X
# USW00003849               ,X
# USW00003849               ,X
# ...                      ...
# USW00013752               ,W
# USW00013752              1,W
# USW00013752               ,W
# USW00013752              2,W
# USW00013752               ,W
#
# [1104 rows x 55 columns]

# %%
def multiLinePlot(df, groupBy, x, y):
    fig, ax = plt.subplots(figsize=(14,10))
    for idx, gp in df.groupby(groupBy):
        gp.plot(x=x, y=y, ax=ax, label=idx)
        
    plt.show()

# %%
groupBy = 'STATION'
x = 'DATE'
y = 'AverageWindSpeed'
multiLinePlot(dfClimate_StationIndex, groupBy, x, y)

# %%
groupBy = 'NAME'
x = 'DATE'
y = 'Precipitation'
multiLinePlot(dfClimate_StationIndex, groupBy, x, y)

# %%
groupBy = 'NAME'
x = 'DATE'
y = 'MaxTemp'
multiLinePlot(dfClimate_StationIndex, groupBy, x, y)

# %% [markdown]
# # Space Weather Data - Cleaning

# %%
#Because my Climate Data goes from 2000-2019, i need to further subset my space weather data for the same date ranges 
isGT2000 = dfSpaceWeather['Year'] >= 2000
dfSpaceWeather = dfSpaceWeather[isGT2000]
isLT2020 = dfSpaceWeather['Year'] < 2020
dfSpaceWeather = dfSpaceWeather[isLT2020]
dfSpaceWeather
# Out:
#        Year  Month  Day  BartelsSolarRotationNumber  \
# 15432  2000      1    1                        2272
# 15433  2000      1    2                        2272
# 15434  2000      1    3                        2272
# 15435  2000      1    4                        2272
# 15436  2000      1    5                        2272
# ...     ...    ...  ...                         ...
# 22732  2019     12   27                        2542
# 22733  2019     12   28                        2542
# 22734  2019     12   29                        2542
# 22735  2019     12   30                        2542
# 22736  2019     12   31                        2542
#
#        NumberofDaywithintheBartels  Kp_0000_0300  Kp_0300_0600  Kp_0600_0900  \
# 15432                            7            53            47            40
# 15433                            8            30            33            33
# 15434                            9            33            30            27
# 15435                           10            23            23            23
# 15436                           11            40            33            33
# ...                            ...           ...           ...           ...
# 22732                           17            10            10            10
# 22733                           18            10             0             0
# 22734                           19             0             0             0
# 22735                           20            10            10             0
# 22736                           21            10            20            10
#
#        Kp_0900_1200  Kp_1200_1500  ...  PlanetaryDailyCharacterFigure  \
# 15432            33            43  ...                            1.3
# 15433            33            27  ...                            0.9
# 15434            27            23  ...                            0.7
# 15435            30            33  ...                            0.7
# 15436            33            23  ...                            1.0
# ...             ...           ...  ...                            ...
# 22732            10             0  ...                            0.0
# 22733             0             0  ...                            0.0
# 22734             0             0  ...                            0.0
# 22735            10             0  ...                            0.0
# 22736            10            10  ...                            0.0
#
#        CpConversion  InternationalSunspotNumber  F10_7  FluxQualifier  \
# 15432           6.0                        48.0  125.6            0.0
# 15433           4.0                        51.0  128.5            0.0
# 15434           3.0                        54.0  128.7            0.0
# 15435           3.0                        64.0  130.3            0.0
# 15436           5.0                        73.0  132.0            0.0
# ...             ...                         ...    ...            ...
# 22732          72.0                         0.0   71.1           68.8
# 22733          72.0                         0.0   71.1           68.9
# 22734          72.0                         0.0   71.1           68.9
# 22735          71.0                         0.0   71.2           69.0
# 22736          71.0                         0.0   71.2           69.0
#
#        Centered81_dayArithmeticAverageofF10_7  \
# 15432                                   160.5
# 15433                                   160.3
# 15434                                   160.0
# 15435                                   159.7
# 15436                                   159.4
# ...                                       ...
# 22732                                    74.4
# 22733                                    74.5
# 22734                                    74.5
# 22735                                    73.4
# 22736                                    73.4
#
#        Last81DayArithmeticAverageofF10_7  ObservedValueOfF10_7  \
# 15432                              175.0                 129.9
# 15433                              174.2                 132.9
# 15434                              173.3                 133.1
# 15435                              172.5                 134.7
# 15436                              171.8                 136.5
# ...                                  ...                   ...
# 22732                               73.3                  70.3
# 22733                               73.3                  70.4
# 22734                               73.4                  70.5
# 22735                               73.4                  70.5
# 22736                               73.5                  70.6
#
#        Centered81DayArithmeticAverageOfF10_7  \
# 15432                                  165.6
# 15433                                  165.3
# 15434                                  165.0
# 15435                                  164.7
# 15436                                  164.4
# ...                                      ...
# 22732                                    NaN
# 22733                                    NaN
# 22734                                    NaN
# 22735                                    NaN
# 22736                                    NaN
#
#        Last81DayArithmeticAverageOfF10_7
# 15432                              179.0
# 15433                              178.3
# 15434                              177.4
# 15435                              176.7
# 15436                              176.0
# ...                                  ...
# 22732                                NaN
# 22733                                NaN
# 22734                                NaN
# 22735                                NaN
# 22736                                NaN
#
# [7305 rows x 33 columns]

# %%
dfSpaceWeather.columns
# Out:
# Index(['Year', 'Month', 'Day', 'BartelsSolarRotationNumber',
#        'NumberofDaywithintheBartels', 'Kp_0000_0300', 'Kp_0300_0600',
#        'Kp_0600_0900', 'Kp_0900_1200', 'Kp_1200_1500', 'Kp_1500_1800',
#        'Kp_1800_2100', 'Kp_2100_0000', 'SumOfKps',
#        'PlanetaryEquivalentAmplitude_0000_0300',
#        'PlanetaryEquivalentAmplitude_0300_0600',
#        'PlanetaryEquivalentAmplitude_0600_0900',
#        'PlanetaryEquivalentAmplitude_0900_1200',
#        'PlanetaryEquivalentAmplitude_1200_1500',
#        'PlanetaryEquivalentAmplitude_1500_1800',
#        'PlanetaryEquivalentAmplitude_1800_2100',
#        'PlanetaryEquivalentAmplitude_2100_0000', 'ArithmeticAverageof8Ap',
#        'PlanetaryDailyCharacterFigure', 'CpConversion',
#        'InternationalSunspotNumber', 'F10_7', 'FluxQualifier',
#        'Centered81_dayArithmeticAverageofF10_7',
#        'Last81DayArithmeticAverageofF10_7', 'ObservedValueOfF10_7',
#        'Centered81DayArithmeticAverageOfF10_7',
#        'Last81DayArithmeticAverageOfF10_7'],
#       dtype='object')

# %%
dfSpaceWeather['Year'].astype('int64')
dfSpaceWeather['Month'].astype('int64')
spaceWeather_Averages = dfSpaceWeather.groupby(['Year','Month']).agg({
    'SumOfKps': 'mean',
    'F10_7' : 'mean',
    'FluxQualifier' : 'mean',
    'Centered81_dayArithmeticAverageofF10_7' : 'mean',
    'Last81DayArithmeticAverageofF10_7' : 'mean', 
    'ObservedValueOfF10_7' : 'mean',
    'Centered81DayArithmeticAverageOfF10_7' : 'mean',
    'Last81DayArithmeticAverageOfF10_7' : 'mean',
    'ArithmeticAverageof8Ap' : 'mean', 
    'PlanetaryDailyCharacterFigure' : 'mean', 
    'InternationalSunspotNumber' : 'mean'
})
spaceWeather_Averages
# Out:
#               SumOfKps       F10_7  FluxQualifier  \
# Year Month
# 2000 1      187.645161  153.067742       0.064516
#      2      205.689655  169.117241       0.068966
#      3      145.322581  206.119355       0.000000
#      4      190.033333  185.490000       0.000000
#      5      196.741935  188.725806       0.064516
# ...                ...         ...            ...
# 2019 8      109.258065   68.661290       0.000000
#      9      151.633333   68.803333       0.000000
#      10     126.032258   67.009677       0.000000
#      11      79.333333   68.663333       0.000000
#      12      67.419355   70.593548      68.380645
#
#             Centered81_dayArithmeticAverageofF10_7  \
# Year Month
# 2000 1                                  162.309677
#      2                                  175.689655
#      3                                  187.287097
#      4                                  192.420000
#      5                                  186.835484
# ...                                            ...
# 2019 8                                   68.987097
#      9                                   68.200000
#      10                                  68.029032
#      11                                  68.796667
#      12                                  73.248387
#
#             Last81DayArithmeticAverageofF10_7  ObservedValueOfF10_7  \
# Year Month
# 2000 1                             171.774194            158.132258
#      2                             160.893103            173.241379
#      3                             170.693548            208.154839
#      4                             184.963333            184.163333
#      5                             191.977419            184.529032
# ...                                       ...                   ...
# 2019 8                              69.619355             66.974194
#      9                              69.096667             68.063333
#      10                             68.448387             67.429032
#      11                             68.026667             70.183333
#      12                             72.683871             69.506452
#
#             Centered81DayArithmeticAverageOfF10_7  \
# Year Month
# 2000 1                                 167.190323
#      2                                 179.472414
#      3                                 188.951613
#      4                                 191.240000
#      5                                 183.041935
# ...                                           ...
# 2019 8                                  67.429032
#      9                                  67.516667
#      10                                 68.416129
#      11                                 70.223333
#      12                                       NaN
#
#             Last81DayArithmeticAverageOfF10_7  ArithmeticAverageof8Ap  \
# Year Month
# 2000 1                             176.454839               12.967742
#      2                             165.889655               15.413793
#      3                             174.983871                8.870968
#      4                             187.373333               15.466667
#      5                             191.729032               15.161290
# ...                                       ...                     ...
# 2019 8                              67.535484                6.870968
#      9                              67.340000                9.833333
#      10                             67.464516                7.387097
#      11                             68.073333                4.200000
#      12                                   NaN                3.064516
#
#             PlanetaryDailyCharacterFigure  InternationalSunspotNumber
# Year Month
# 2000 1                           0.632258                   90.096774
#      2                           0.720690                  112.862069
#      3                           0.435484                  138.483871
#      4                           0.660000                  125.533333
#      5                           0.661290                  121.580645
# ...                                   ...                         ...
# 2019 8                           0.264516                    0.483871
#      9                           0.463333                    1.100000
#      10                          0.358065                    0.419355
#      11                          0.156667                    0.500000
#      12                          1.870968                    0.000000
#
# [240 rows x 11 columns]

# %% [markdown]
# # Climate Data - Cleaning

# %%
dfClimate.STATION.unique()
# Out:
# array(['USW00003849', 'USW00004110', 'USW00003919', 'USW00094626',
#        'USW00013752'], dtype=object)

# %%
#Break Climate Data up to only show columns:AverageWindSpeed, Precipitation, Snowfall, AverageTemp and TotalSunshinePeriod, Ap, Cp
sub_columns = ['DATE', 'NAME', 'AverageWindSpeed','Precipitation','Snowfall','AverageTemp','TotalSunshinePeriod']
dfClimate = dfClimate[sub_columns]
dfClimate.head()
# Out:
#       DATE                          NAME  AverageWindSpeed  Precipitation  \
# 0  2000-01  LONDON CORBIN AIRPORT, KY US               6.7           3.27
# 1  2000-02  LONDON CORBIN AIRPORT, KY US               6.3           3.51
# 2  2000-03  LONDON CORBIN AIRPORT, KY US               5.8           2.54
# 3  2000-04  LONDON CORBIN AIRPORT, KY US               6.3           5.21
# 4  2000-05  LONDON CORBIN AIRPORT, KY US               5.6           3.10
#
#    Snowfall  AverageTemp  TotalSunshinePeriod
# 0       NaN         33.9                  NaN
# 1       NaN         43.0                  NaN
# 2       NaN         50.8                  NaN
# 3       NaN         54.0                  NaN
# 4       NaN         66.7                  NaN

# %%
#Need to look at the values of snowfall to see if they are all NaN, if so, it will not be a good variable 
dfClimate.Snowfall.unique()
# Out:
# array([nan])

# %%
#Also need to look at values of TotalSunshinePeriod to see if they are all NaN
dfClimate.TotalSunshinePeriod.unique()
# Out:
# array([nan,  0.])

# %%
#Remove snowfall and TotalSunshinePeriod from the subset 
del dfClimate['Snowfall']
del dfClimate['TotalSunshinePeriod']
dfClimate
# Out:
#          DATE                          NAME  AverageWindSpeed  Precipitation  \
# 0     2000-01  LONDON CORBIN AIRPORT, KY US               6.7           3.27
# 1     2000-02  LONDON CORBIN AIRPORT, KY US               6.3           3.51
# 2     2000-03  LONDON CORBIN AIRPORT, KY US               5.8           2.54
# 3     2000-04  LONDON CORBIN AIRPORT, KY US               6.3           5.21
# 4     2000-05  LONDON CORBIN AIRPORT, KY US               5.6           3.10
# ...       ...                           ...               ...            ...
# 1099  2019-08          ANNAPOLIS NAF, MD US               5.8           1.50
# 1100  2019-09          ANNAPOLIS NAF, MD US               6.5           0.25
# 1101  2019-10          ANNAPOLIS NAF, MD US               7.6           4.44
# 1102  2019-11          ANNAPOLIS NAF, MD US               6.9           0.73
# 1103  2019-12          ANNAPOLIS NAF, MD US               5.6           1.98
#
#       AverageTemp
# 0            33.9
# 1            43.0
# 2            50.8
# 3            54.0
# 4            66.7
# ...           ...
# 1099         80.7
# 1100         76.1
# 1101         62.4
# 1102         45.0
# 1103         40.7
#
# [1104 rows x 5 columns]

# %%
#Group climate data by date
dfClimate[['Year','Month']] = dfClimate['DATE'].str.split('-',expand=True)
# Out:
# c:\users\heath\.conda\envs\opencv\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
del dfClimate['DATE']
dfClimate
# Out:
#                               NAME  AverageWindSpeed  Precipitation  \
# 0     LONDON CORBIN AIRPORT, KY US               6.7           3.27
# 1     LONDON CORBIN AIRPORT, KY US               6.3           3.51
# 2     LONDON CORBIN AIRPORT, KY US               5.8           2.54
# 3     LONDON CORBIN AIRPORT, KY US               6.3           5.21
# 4     LONDON CORBIN AIRPORT, KY US               5.6           3.10
# ...                            ...               ...            ...
# 1099          ANNAPOLIS NAF, MD US               5.8           1.50
# 1100          ANNAPOLIS NAF, MD US               6.5           0.25
# 1101          ANNAPOLIS NAF, MD US               7.6           4.44
# 1102          ANNAPOLIS NAF, MD US               6.9           0.73
# 1103          ANNAPOLIS NAF, MD US               5.6           1.98
#
#       AverageTemp  Year Month
# 0            33.9  2000    01
# 1            43.0  2000    02
# 2            50.8  2000    03
# 3            54.0  2000    04
# 4            66.7  2000    05
# ...           ...   ...   ...
# 1099         80.7  2019    08
# 1100         76.1  2019    09
# 1101         62.4  2019    10
# 1102         45.0  2019    11
# 1103         40.7  2019    12
#
# [1104 rows x 6 columns]

# %% [markdown]
# # Data Merging

# %%
dfClimate['Year'] = dfClimate.Year.astype('int64')
dfClimate['Month'] = dfClimate.Month.astype('int64')
dfClimate = pd.DataFrame(dfClimate.set_index(['Year', 'Month']))
dfClimate
# Out:
# c:\users\heath\.conda\envs\opencv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\heath\.conda\envs\opencv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                     NAME  AverageWindSpeed  Precipitation  \
# Year Month
# 2000 1      LONDON CORBIN AIRPORT, KY US               6.7           3.27
#      2      LONDON CORBIN AIRPORT, KY US               6.3           3.51
#      3      LONDON CORBIN AIRPORT, KY US               5.8           2.54
#      4      LONDON CORBIN AIRPORT, KY US               6.3           5.21
#      5      LONDON CORBIN AIRPORT, KY US               5.6           3.10
# ...                                  ...               ...            ...
# 2019 8              ANNAPOLIS NAF, MD US               5.8           1.50
#      9              ANNAPOLIS NAF, MD US               6.5           0.25
#      10             ANNAPOLIS NAF, MD US               7.6           4.44
#      11             ANNAPOLIS NAF, MD US               6.9           0.73
#      12             ANNAPOLIS NAF, MD US               5.6           1.98
#
#             AverageTemp
# Year Month
# 2000 1             33.9
#      2             43.0
#      3             50.8
#      4             54.0
#      5             66.7
# ...                 ...
# 2019 8             80.7
#      9             76.1
#      10            62.4
#      11            45.0
#      12            40.7
#
# [1104 rows x 4 columns]

# %%
# Perform an inner join on the employees and departments data frames 
dfMergedData = pd.merge(spaceWeather_Averages, dfClimate, how = 'right', left_on=None, right_on=None, left_index=True, right_index=True)

# %%
dfMergedData
# Out:
#               SumOfKps       F10_7  FluxQualifier  \
# Year Month
# 2000 1      187.645161  153.067742       0.064516
#      1      187.645161  153.067742       0.064516
#      1      187.645161  153.067742       0.064516
#      1      187.645161  153.067742       0.064516
#      2      205.689655  169.117241       0.068966
# ...                ...         ...            ...
# 2019 12      67.419355   70.593548      68.380645
#      12      67.419355   70.593548      68.380645
#      12      67.419355   70.593548      68.380645
#      12      67.419355   70.593548      68.380645
#      12      67.419355   70.593548      68.380645
#
#             Centered81_dayArithmeticAverageofF10_7  \
# Year Month
# 2000 1                                  162.309677
#      1                                  162.309677
#      1                                  162.309677
#      1                                  162.309677
#      2                                  175.689655
# ...                                            ...
# 2019 12                                  73.248387
#      12                                  73.248387
#      12                                  73.248387
#      12                                  73.248387
#      12                                  73.248387
#
#             Last81DayArithmeticAverageofF10_7  ObservedValueOfF10_7  \
# Year Month
# 2000 1                             171.774194            158.132258
#      1                             171.774194            158.132258
#      1                             171.774194            158.132258
#      1                             171.774194            158.132258
#      2                             160.893103            173.241379
# ...                                       ...                   ...
# 2019 12                             72.683871             69.506452
#      12                             72.683871             69.506452
#      12                             72.683871             69.506452
#      12                             72.683871             69.506452
#      12                             72.683871             69.506452
#
#             Centered81DayArithmeticAverageOfF10_7  \
# Year Month
# 2000 1                                 167.190323
#      1                                 167.190323
#      1                                 167.190323
#      1                                 167.190323
#      2                                 179.472414
# ...                                           ...
# 2019 12                                       NaN
#      12                                       NaN
#      12                                       NaN
#      12                                       NaN
#      12                                       NaN
#
#             Last81DayArithmeticAverageOfF10_7  ArithmeticAverageof8Ap  \
# Year Month
# 2000 1                             176.454839               12.967742
#      1                             176.454839               12.967742
#      1                             176.454839               12.967742
#      1                             176.454839               12.967742
#      2                             165.889655               15.413793
# ...                                       ...                     ...
# 2019 12                                   NaN                3.064516
#      12                                   NaN                3.064516
#      12                                   NaN                3.064516
#      12                                   NaN                3.064516
#      12                                   NaN                3.064516
#
#             PlanetaryDailyCharacterFigure  InternationalSunspotNumber  \
# Year Month
# 2000 1                           0.632258                   90.096774
#      1                           0.632258                   90.096774
#      1                           0.632258                   90.096774
#      1                           0.632258                   90.096774
#      2                           0.720690                  112.862069
# ...                                   ...                         ...
# 2019 12                          1.870968                    0.000000
#      12                          1.870968                    0.000000
#      12                          1.870968                    0.000000
#      12                          1.870968                    0.000000
#      12                          1.870968                    0.000000
#
#                                                 NAME  AverageWindSpeed  \
# Year Month
# 2000 1                  LONDON CORBIN AIRPORT, KY US               6.7
#      1                      JEROME CO AIRPORT, ID US              11.2
#      1               SALINA MUNICIPAL AIRPORT, KS US               8.7
#      1      GREENVILLE MAINE FORESTRY SERVICE, ME US              11.6
#      2                  LONDON CORBIN AIRPORT, KY US               6.3
# ...                                              ...               ...
# 2019 12                 LONDON CORBIN AIRPORT, KY US               5.1
#      12                     JEROME CO AIRPORT, ID US              11.6
#      12              SALINA MUNICIPAL AIRPORT, KS US               9.6
#      12     GREENVILLE MAINE FORESTRY SERVICE, ME US               9.4
#      12                         ANNAPOLIS NAF, MD US               5.6
#
#             Precipitation  AverageTemp
# Year Month
# 2000 1               3.27         33.9
#      1               2.10         29.7
#      1               0.27         32.1
#      1               1.96         14.0
#      2               3.51         43.0
# ...                   ...          ...
# 2019 12              6.35         43.6
#      12              0.91         30.4
#      12              1.44         35.6
#      12              2.95         22.5
#      12              1.98         40.7
#
# [1104 rows x 15 columns]

# %%
dfFinal = dfMergedData.set_index('NAME',append=True)
dfFinal.head()
# Out:
#                                                        SumOfKps       F10_7  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US              187.645161  153.067742
#            JEROME CO AIRPORT, ID US                  187.645161  153.067742
#            SALINA MUNICIPAL AIRPORT, KS US           187.645161  153.067742
#            GREENVILLE MAINE FORESTRY SERVICE, ME US  187.645161  153.067742
#      2     LONDON CORBIN AIRPORT, KY US              205.689655  169.117241
#
#                                                      FluxQualifier  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                   0.064516
#            JEROME CO AIRPORT, ID US                       0.064516
#            SALINA MUNICIPAL AIRPORT, KS US                0.064516
#            GREENVILLE MAINE FORESTRY SERVICE, ME US       0.064516
#      2     LONDON CORBIN AIRPORT, KY US                   0.068966
#
#                                                      Centered81_dayArithmeticAverageofF10_7  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                                          162.309677
#            JEROME CO AIRPORT, ID US                                              162.309677
#            SALINA MUNICIPAL AIRPORT, KS US                                       162.309677
#            GREENVILLE MAINE FORESTRY SERVICE, ME US                              162.309677
#      2     LONDON CORBIN AIRPORT, KY US                                          175.689655
#
#                                                      Last81DayArithmeticAverageofF10_7  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                                     171.774194
#            JEROME CO AIRPORT, ID US                                         171.774194
#            SALINA MUNICIPAL AIRPORT, KS US                                  171.774194
#            GREENVILLE MAINE FORESTRY SERVICE, ME US                         171.774194
#      2     LONDON CORBIN AIRPORT, KY US                                     160.893103
#
#                                                      ObservedValueOfF10_7  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                        158.132258
#            JEROME CO AIRPORT, ID US                            158.132258
#            SALINA MUNICIPAL AIRPORT, KS US                     158.132258
#            GREENVILLE MAINE FORESTRY SERVICE, ME US            158.132258
#      2     LONDON CORBIN AIRPORT, KY US                        173.241379
#
#                                                      Centered81DayArithmeticAverageOfF10_7  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                                         167.190323
#            JEROME CO AIRPORT, ID US                                             167.190323
#            SALINA MUNICIPAL AIRPORT, KS US                                      167.190323
#            GREENVILLE MAINE FORESTRY SERVICE, ME US                             167.190323
#      2     LONDON CORBIN AIRPORT, KY US                                         179.472414
#
#                                                      Last81DayArithmeticAverageOfF10_7  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                                     176.454839
#            JEROME CO AIRPORT, ID US                                         176.454839
#            SALINA MUNICIPAL AIRPORT, KS US                                  176.454839
#            GREENVILLE MAINE FORESTRY SERVICE, ME US                         176.454839
#      2     LONDON CORBIN AIRPORT, KY US                                     165.889655
#
#                                                      ArithmeticAverageof8Ap  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                           12.967742
#            JEROME CO AIRPORT, ID US                               12.967742
#            SALINA MUNICIPAL AIRPORT, KS US                        12.967742
#            GREENVILLE MAINE FORESTRY SERVICE, ME US               12.967742
#      2     LONDON CORBIN AIRPORT, KY US                           15.413793
#
#                                                      PlanetaryDailyCharacterFigure  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                                   0.632258
#            JEROME CO AIRPORT, ID US                                       0.632258
#            SALINA MUNICIPAL AIRPORT, KS US                                0.632258
#            GREENVILLE MAINE FORESTRY SERVICE, ME US                       0.632258
#      2     LONDON CORBIN AIRPORT, KY US                                   0.720690
#
#                                                      InternationalSunspotNumber  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                               90.096774
#            JEROME CO AIRPORT, ID US                                   90.096774
#            SALINA MUNICIPAL AIRPORT, KS US                            90.096774
#            GREENVILLE MAINE FORESTRY SERVICE, ME US                   90.096774
#      2     LONDON CORBIN AIRPORT, KY US                              112.862069
#
#                                                      AverageWindSpeed  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                           6.7
#            JEROME CO AIRPORT, ID US                              11.2
#            SALINA MUNICIPAL AIRPORT, KS US                        8.7
#            GREENVILLE MAINE FORESTRY SERVICE, ME US              11.6
#      2     LONDON CORBIN AIRPORT, KY US                           6.3
#
#                                                      Precipitation  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                       3.27
#            JEROME CO AIRPORT, ID US                           2.10
#            SALINA MUNICIPAL AIRPORT, KS US                    0.27
#            GREENVILLE MAINE FORESTRY SERVICE, ME US           1.96
#      2     LONDON CORBIN AIRPORT, KY US                       3.51
#
#                                                      AverageTemp
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                     33.9
#            JEROME CO AIRPORT, ID US                         29.7
#            SALINA MUNICIPAL AIRPORT, KS US                  32.1
#            GREENVILLE MAINE FORESTRY SERVICE, ME US         14.0
#      2     LONDON CORBIN AIRPORT, KY US                     43.0

# %% [markdown]
# # Merged Data Visualization

# %%
dfFinal.AverageWindSpeed.unstack(level=0).plot(kind='line', subplots=False)

# %%
dfFinal.AverageWindSpeed.unstack(level=0).plot(kind='line', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B41CDE08>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B407D288>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B40B2A88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B40EE588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B4120FC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B415CD88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B41D6A08>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B3C74888>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B3A7D7C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B3D0D188>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B39D9D08>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B39BD208>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B380F348>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A137DCC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B3789F48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B3A06308>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B3CEC308>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B39BEEC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B418CAC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8B3AA6708>],
#       dtype=object)

# %%
corr = dfFinal.corr()
plt.subplots(figsize=(20,15))
ax = sns.heatmap(corr, vmin=-1, vmax=1,center=0,cmap=sns.diverging_palette(20, 220, n=200), square=True)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right')
# Out:
# [Text(0.5, 0, 'SumOfKps'),
#  Text(1.5, 0, 'F10_7'),
#  Text(2.5, 0, 'FluxQualifier'),
#  Text(3.5, 0, 'Centered81_dayArithmeticAverageofF10_7'),
#  Text(4.5, 0, 'Last81DayArithmeticAverageofF10_7'),
#  Text(5.5, 0, 'ObservedValueOfF10_7'),
#  Text(6.5, 0, 'Centered81DayArithmeticAverageOfF10_7'),
#  Text(7.5, 0, 'Last81DayArithmeticAverageOfF10_7'),
#  Text(8.5, 0, 'ArithmeticAverageof8Ap'),
#  Text(9.5, 0, 'PlanetaryDailyCharacterFigure'),
#  Text(10.5, 0, 'InternationalSunspotNumber'),
#  Text(11.5, 0, 'AverageWindSpeed'),
#  Text(12.5, 0, 'Precipitation'),
#  Text(13.5, 0, 'AverageTemp')]

# %% [markdown]
# #### Strong Positive Correlations:
# ##### - SumOfKps/ArithmeticAverageOf8Aps
# ##### - F10_7/InternationalSunspotNumber
# ##### - SumOfKps/PlanetaryDailyCharacterFigure
# #### Strong Negative Correlations:
# ##### - AverageWindSpeed/AverageTemp
#
# #### Unfortunately i do not see any correlations between my space weather and my climate data. There are some strong correlations between all of the F10.7 values which i would expect, but it is not important to me.

# %%
dfFinal.columns
# Out:
# Index(['SumOfKps', 'F10_7', 'FluxQualifier',
#        'Centered81_dayArithmeticAverageofF10_7',
#        'Last81DayArithmeticAverageofF10_7', 'ObservedValueOfF10_7',
#        'Centered81DayArithmeticAverageOfF10_7',
#        'Last81DayArithmeticAverageOfF10_7', 'ArithmeticAverageof8Ap',
#        'PlanetaryDailyCharacterFigure', 'InternationalSunspotNumber',
#        'AverageWindSpeed', 'Precipitation', 'AverageTemp'],
#       dtype='object')

# %%
sub_columns = ['SumOfKps','F10_7','FluxQualifier','ArithmeticAverageof8Ap','PlanetaryDailyCharacterFigure','InternationalSunspotNumber','AverageWindSpeed','Precipitation','AverageTemp']
df = dfFinal[sub_columns]

# %%
g = sns.pairplot(df)
