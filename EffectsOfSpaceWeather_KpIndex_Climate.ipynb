# %% [markdown]
# # Effects Of Space Weather
# ## MSDS 696 Practicum II
# #### Regis University
# #### Heather Holcomb
#
# #### How does the Kp index, or geomagnetic activity effect climate?

# %%
# Load necessary libraries 
import re
import pandas as pd
import os
import matplotlib.pyplot as plt
import netCDF4
import seaborn as sns
import numpy as np 
import statsmodels.formula.api as smf
import statsmodels.api
import fbprophet
import random

from netCDF4 import Dataset
from scipy import stats
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from gekko import GEKKO
from scipy.optimize import minimize
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %% [markdown]
# # Load/Clean Space Weather Data

# %%
dfSpaceWeather = pd.read_csv('Data\SpaceWeatherData_Cleaned', header = 0, delimiter=r"\s+")
dfSpaceWeather.columns
# Out:
# Index(['yy', 'mm', 'dd', 'BSRN', 'ND', 'Kp', 'Kp.1', 'Kp.2', 'Kp.3', 'Kp.4',
#        'Kp.5', 'Kp.6', 'Kp.7', 'Sum', 'Ap', 'Ap.1', 'Ap.2', 'Ap.3', 'Ap.4',
#        'Ap.5', 'Ap.6', 'Ap.7', 'Avg', 'Cp', 'C9', 'ISN', 'F10.7', 'Q', 'Ctr81',
#        'Lst81', 'F10.7.1', 'Ctr81.1', 'Lst81.1'],
#       dtype='object')

# %%
#Rename columns to make sense 
dfSpaceWeather = dfSpaceWeather.rename(columns={
    "yy": "Year", 
    "mm": "Month", 
    "dd": "Day", 
    "BSRN": "BartelsSolarRotationNumber", 
    "ND": "NumberofDaywithintheBartels", 
    "Kp": "Kp_0000_0300", 
    "Kp.1": "Kp_0300_0600", 
    "Kp.2": "Kp_0600_0900", 
    "Kp.3": "Kp_0900_1200", 
    "Kp.4": "Kp_1200_1500",
    "Kp.5": "Kp_1500_1800",
    "Kp.6": "Kp_1800_2100",
    "Kp.7": "Kp_2100_0000",
    "Sum": "SumOfKps", 
    "Ap": "PlanetaryEquivalentAmplitude_0000_0300",
    "Ap.1": "PlanetaryEquivalentAmplitude_0300_0600",
    "Ap.2": "PlanetaryEquivalentAmplitude_0600_0900",
    "Ap.3": "PlanetaryEquivalentAmplitude_0900_1200",
    "Ap.4": "PlanetaryEquivalentAmplitude_1200_1500",
    "Ap.5": "PlanetaryEquivalentAmplitude_1500_1800",
    "Ap.6": "PlanetaryEquivalentAmplitude_1800_2100",
    "Ap.7": "PlanetaryEquivalentAmplitude_2100_0000",
    "Avg": "ArithmeticAverageof8Ap",
    "Cp": "PlanetaryDailyCharacterFigure", 
    "C9": "CpConversion", 
    "ISN": "InternationalSunspotNumber",
    "F10.7": "F10_7",
    "Q": "FluxQualifier",
    "Ctr81": "Centered81_dayArithmeticAverageofF10_7",
    "Lst81": "Last81DayArithmeticAverageofF10_7", 
    "F10.7.1": "ObservedValueOfF10_7",
    "Ctr81.1": "Centered81DayArithmeticAverageOfF10_7",
    "Lst81.1": "Last81DayArithmeticAverageOfF10_7"})

# %%
spaceWeather_dict = dfSpaceWeather.groupby(['Year','Month']).agg({
    'SumOfKps': 'mean',
    'ArithmeticAverageof8Ap': 'mean',
    'PlanetaryDailyCharacterFigure': 'mean',
    'NumberofDaywithintheBartels' : 'mean',
    'PlanetaryDailyCharacterFigure' : 'mean',
    'CpConversion' : 'mean',
    'InternationalSunspotNumber' : 'mean',
    'F10_7' : 'mean',
    'FluxQualifier' : 'mean',
    'Centered81_dayArithmeticAverageofF10_7' : 'mean',
    'Last81DayArithmeticAverageofF10_7' : 'mean',
    'ObservedValueOfF10_7' : 'mean',
    'Centered81DayArithmeticAverageOfF10_7' : 'mean',
    'Last81DayArithmeticAverageOfF10_7' : 'mean'
})
spaceWeather_dict
# Out:
#               SumOfKps  ArithmeticAverageof8Ap  PlanetaryDailyCharacterFigure  \
# Year Month
# 1957 10     198.612903               13.774194                       0.683871
#      11     223.766667               18.033333                       0.810000
#      12     232.483871               17.741935                       0.841935
# 1958 1      208.387097               14.741935                       0.738710
#      2      265.642857               26.857143                       0.978571
# ...                ...                     ...                            ...
# 2019 11      79.333333                4.200000                       0.156667
#      12      67.419355                3.064516                       1.870968
# 2020 1       98.709677                4.806452                       5.935484
#      2      126.206897                6.413793                       0.379310
#      3      107.636364                4.818182                      15.181818
#
#             NumberofDaywithintheBartels  CpConversion  \
# Year Month
# 1957 10                       14.838710      3.225806
#      11                       15.000000      3.700000
#      12                       14.000000      3.903226
# 1958 1                        12.774194      3.354839
#      2                        13.750000      4.500000
# ...                                 ...           ...
# 2019 11                       14.200000      0.566667
#      12                       14.709677     70.967742
# 2020 1                        15.225806     72.322581
#      2                        14.862069     71.034483
#      3                         6.000000     57.181818
#
#             InternationalSunspotNumber       F10_7  FluxQualifier  \
# Year Month
# 1957 10                     253.806452  281.225806       0.000000
#      11                     210.866667  256.100000       0.000000
#      12                     239.419355  284.322581       0.129032
# 1958 1                      202.451613  247.870968       0.000000
#      2                      164.928571  209.857143       0.142857
# ...                                ...         ...            ...
# 2019 11                       0.500000   68.663333       0.000000
#      12                       0.000000   70.593548      68.380645
# 2020 1                        0.000000   71.490323      70.090323
#      2                        0.000000   71.275862      71.362069
#      3                       12.909091   71.163636      71.581818
#
#             Centered81_dayArithmeticAverageofF10_7  \
# Year Month
# 1957 10                                 269.212903
#      11                                 270.756667
#      12                                 268.045161
# 1958 1                                  251.338710
#      2                                  233.932143
# ...                                            ...
# 2019 11                                  68.796667
#      12                                  73.248387
# 2020 1                                   74.709677
#      2                                   72.800000
#      3                                   71.172727
#
#             Last81DayArithmeticAverageofF10_7  ObservedValueOfF10_7  \
# Year Month
# 1957 10                            241.138710            283.109677
#      11                            266.740000            259.216667
#      12                            269.800000            289.358065
# 1958 1                             271.277419            251.506452
#      2                             257.303571            211.796429
# ...                                       ...                   ...
# 2019 11                             68.026667             70.183333
#      12                             72.683871             69.506452
# 2020 1                              73.658065             72.035484
#      2                              72.906897             73.586207
#      3                              72.409091             73.577778
#
#             Centered81DayArithmeticAverageOfF10_7  \
# Year Month
# 1957 10                                271.119355
#      11                                274.023333
#      12                                272.129032
# 1958 1                                 254.929032
#      2                                 236.132143
# ...                                           ...
# 2019 11                                 70.223333
#      12                                       NaN
# 2020 1                                        NaN
#      2                                        NaN
#      3                                        NaN
#
#             Last81DayArithmeticAverageOfF10_7
# Year Month
# 1957 10                            241.803226
#      11                            268.293333
#      12                            272.619355
# 1958 1                             275.267742
#      2                             261.185714
# ...                                       ...
# 2019 11                             68.073333
#      12                                   NaN
# 2020 1                                    NaN
#      2                                    NaN
#      3                                    NaN
#
# [750 rows x 13 columns]

# %%
dfSpaceWeatherAverage = pd.DataFrame(spaceWeather_dict)

# %%
#Because my Climate Data goes from 2000-2019, i need to further subset my space weather data for the same date ranges 
isGT2000 = dfSpaceWeather['Year'] >= 2000
dfSpaceWeather = dfSpaceWeather[isGT2000]
isLT2020 = dfSpaceWeather['Year'] < 2020
dfSpaceWeather = dfSpaceWeather[isLT2020]
dfSpaceWeather
# Out:
#        Year  Month  Day  BartelsSolarRotationNumber  \
# 15432  2000      1    1                        2272
# 15433  2000      1    2                        2272
# 15434  2000      1    3                        2272
# 15435  2000      1    4                        2272
# 15436  2000      1    5                        2272
# ...     ...    ...  ...                         ...
# 22732  2019     12   27                        2542
# 22733  2019     12   28                        2542
# 22734  2019     12   29                        2542
# 22735  2019     12   30                        2542
# 22736  2019     12   31                        2542
#
#        NumberofDaywithintheBartels  Kp_0000_0300  Kp_0300_0600  Kp_0600_0900  \
# 15432                            7            53            47            40
# 15433                            8            30            33            33
# 15434                            9            33            30            27
# 15435                           10            23            23            23
# 15436                           11            40            33            33
# ...                            ...           ...           ...           ...
# 22732                           17            10            10            10
# 22733                           18            10             0             0
# 22734                           19             0             0             0
# 22735                           20            10            10             0
# 22736                           21            10            20            10
#
#        Kp_0900_1200  Kp_1200_1500  ...  PlanetaryDailyCharacterFigure  \
# 15432            33            43  ...                            1.3
# 15433            33            27  ...                            0.9
# 15434            27            23  ...                            0.7
# 15435            30            33  ...                            0.7
# 15436            33            23  ...                            1.0
# ...             ...           ...  ...                            ...
# 22732            10             0  ...                            0.0
# 22733             0             0  ...                            0.0
# 22734             0             0  ...                            0.0
# 22735            10             0  ...                            0.0
# 22736            10            10  ...                            0.0
#
#        CpConversion  InternationalSunspotNumber  F10_7  FluxQualifier  \
# 15432           6.0                        48.0  125.6            0.0
# 15433           4.0                        51.0  128.5            0.0
# 15434           3.0                        54.0  128.7            0.0
# 15435           3.0                        64.0  130.3            0.0
# 15436           5.0                        73.0  132.0            0.0
# ...             ...                         ...    ...            ...
# 22732          72.0                         0.0   71.1           68.8
# 22733          72.0                         0.0   71.1           68.9
# 22734          72.0                         0.0   71.1           68.9
# 22735          71.0                         0.0   71.2           69.0
# 22736          71.0                         0.0   71.2           69.0
#
#        Centered81_dayArithmeticAverageofF10_7  \
# 15432                                   160.5
# 15433                                   160.3
# 15434                                   160.0
# 15435                                   159.7
# 15436                                   159.4
# ...                                       ...
# 22732                                    74.4
# 22733                                    74.5
# 22734                                    74.5
# 22735                                    73.4
# 22736                                    73.4
#
#        Last81DayArithmeticAverageofF10_7  ObservedValueOfF10_7  \
# 15432                              175.0                 129.9
# 15433                              174.2                 132.9
# 15434                              173.3                 133.1
# 15435                              172.5                 134.7
# 15436                              171.8                 136.5
# ...                                  ...                   ...
# 22732                               73.3                  70.3
# 22733                               73.3                  70.4
# 22734                               73.4                  70.5
# 22735                               73.4                  70.5
# 22736                               73.5                  70.6
#
#        Centered81DayArithmeticAverageOfF10_7  \
# 15432                                  165.6
# 15433                                  165.3
# 15434                                  165.0
# 15435                                  164.7
# 15436                                  164.4
# ...                                      ...
# 22732                                    NaN
# 22733                                    NaN
# 22734                                    NaN
# 22735                                    NaN
# 22736                                    NaN
#
#        Last81DayArithmeticAverageOfF10_7
# 15432                              179.0
# 15433                              178.3
# 15434                              177.4
# 15435                              176.7
# 15436                              176.0
# ...                                  ...
# 22732                                NaN
# 22733                                NaN
# 22734                                NaN
# 22735                                NaN
# 22736                                NaN
#
# [7305 rows x 33 columns]

# %%
dfSpaceWeather['Year'].astype('int64')
dfSpaceWeather['Month'].astype('int64')
spaceWeather_Averages = dfSpaceWeather.groupby(['Year','Month']).agg({
    'SumOfKps': 'mean',
    'F10_7' : 'mean',
    'FluxQualifier' : 'mean',
    'Centered81_dayArithmeticAverageofF10_7' : 'mean',
    'Last81DayArithmeticAverageofF10_7' : 'mean', 
    'ObservedValueOfF10_7' : 'mean',
    'Centered81DayArithmeticAverageOfF10_7' : 'mean',
    'Last81DayArithmeticAverageOfF10_7' : 'mean',
    'ArithmeticAverageof8Ap' : 'mean', 
    'PlanetaryDailyCharacterFigure' : 'mean', 
    'InternationalSunspotNumber' : 'mean'
})
spaceWeather_Averages
# Out:
#               SumOfKps       F10_7  FluxQualifier  \
# Year Month
# 2000 1      187.645161  153.067742       0.064516
#      2      205.689655  169.117241       0.068966
#      3      145.322581  206.119355       0.000000
#      4      190.033333  185.490000       0.000000
#      5      196.741935  188.725806       0.064516
# ...                ...         ...            ...
# 2019 8      109.258065   68.661290       0.000000
#      9      151.633333   68.803333       0.000000
#      10     126.032258   67.009677       0.000000
#      11      79.333333   68.663333       0.000000
#      12      67.419355   70.593548      68.380645
#
#             Centered81_dayArithmeticAverageofF10_7  \
# Year Month
# 2000 1                                  162.309677
#      2                                  175.689655
#      3                                  187.287097
#      4                                  192.420000
#      5                                  186.835484
# ...                                            ...
# 2019 8                                   68.987097
#      9                                   68.200000
#      10                                  68.029032
#      11                                  68.796667
#      12                                  73.248387
#
#             Last81DayArithmeticAverageofF10_7  ObservedValueOfF10_7  \
# Year Month
# 2000 1                             171.774194            158.132258
#      2                             160.893103            173.241379
#      3                             170.693548            208.154839
#      4                             184.963333            184.163333
#      5                             191.977419            184.529032
# ...                                       ...                   ...
# 2019 8                              69.619355             66.974194
#      9                              69.096667             68.063333
#      10                             68.448387             67.429032
#      11                             68.026667             70.183333
#      12                             72.683871             69.506452
#
#             Centered81DayArithmeticAverageOfF10_7  \
# Year Month
# 2000 1                                 167.190323
#      2                                 179.472414
#      3                                 188.951613
#      4                                 191.240000
#      5                                 183.041935
# ...                                           ...
# 2019 8                                  67.429032
#      9                                  67.516667
#      10                                 68.416129
#      11                                 70.223333
#      12                                       NaN
#
#             Last81DayArithmeticAverageOfF10_7  ArithmeticAverageof8Ap  \
# Year Month
# 2000 1                             176.454839               12.967742
#      2                             165.889655               15.413793
#      3                             174.983871                8.870968
#      4                             187.373333               15.466667
#      5                             191.729032               15.161290
# ...                                       ...                     ...
# 2019 8                              67.535484                6.870968
#      9                              67.340000                9.833333
#      10                             67.464516                7.387097
#      11                             68.073333                4.200000
#      12                                   NaN                3.064516
#
#             PlanetaryDailyCharacterFigure  InternationalSunspotNumber
# Year Month
# 2000 1                           0.632258                   90.096774
#      2                           0.720690                  112.862069
#      3                           0.435484                  138.483871
#      4                           0.660000                  125.533333
#      5                           0.661290                  121.580645
# ...                                   ...                         ...
# 2019 8                           0.264516                    0.483871
#      9                           0.463333                    1.100000
#      10                          0.358065                    0.419355
#      11                          0.156667                    0.500000
#      12                          1.870968                    0.000000
#
# [240 rows x 11 columns]

# %% [markdown]
# # Load/Clean Climate Data

# %%
dfClimate = pd.read_csv('Data\Weather\MonthlyClimate.csv', header = 0, delimiter=r",")
dfClimate.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'AWND',
#        'AWND_ATTRIBUTES', 'CDSD', 'CDSD_ATTRIBUTES', 'CLDD', 'CLDD_ATTRIBUTES',
#        'DP01', 'DP01_ATTRIBUTES', 'DP10', 'DP10_ATTRIBUTES', 'DT00',
#        'DT00_ATTRIBUTES', 'DT32', 'DT32_ATTRIBUTES', 'DX32', 'DX32_ATTRIBUTES',
#        'DX70', 'DX70_ATTRIBUTES', 'DX90', 'DX90_ATTRIBUTES', 'EMNT',
#        'EMNT_ATTRIBUTES', 'EMXP', 'EMXP_ATTRIBUTES', 'EMXT', 'EMXT_ATTRIBUTES',
#        'HDSD', 'HDSD_ATTRIBUTES', 'HTDD', 'HTDD_ATTRIBUTES', 'PRCP',
#        'PRCP_ATTRIBUTES', 'SNOW', 'SNOW_ATTRIBUTES', 'TAVG', 'TAVG_ATTRIBUTES',
#        'TMAX', 'TMAX_ATTRIBUTES', 'TMIN', 'TMIN_ATTRIBUTES', 'TSUN',
#        'TSUN_ATTRIBUTES', 'WDF2', 'WDF2_ATTRIBUTES', 'WDF5', 'WDF5_ATTRIBUTES',
#        'WSF2', 'WSF2_ATTRIBUTES', 'WSF5', 'WSF5_ATTRIBUTES'],
#       dtype='object')

# %%
#Rename columns to make sense 
dfClimate = dfClimate.rename(columns={
    "EMXP": "ExtremeMaxPrecip",
    "EMXT": "ExtremeMaxTemp",
    "PRCP": "Precipitation",
    "DX90": "DaysMaxTempGT90F",
    "DP10": "DaysMoreThan1InchRain",
    "DX70": "DaysMaxTempGT70F",
    "EMNT": "ExtremeMinTemp",
    "DT32": "DaysMinTempLT32F",
    "WDF2": "DirFast2MinWind",
    "DX32": "DaysMaxTempLT32F",
    "WDF5": "DirFast5MinWind",
    "TMAX": "MaxTemp",
    "WSF2": "SpeedFast2MinWind",
    "WSF5": "SpeedFast5MinWind",
    "SNOW": "Snowfall",
    "HDSD": "HeatDegDaysSeasonToDate",
    "HTDD": "HeatDegDays",
    "DP01": "DaysWithGTTenthInchPrecip",
    "CDSD": "CoolDegDaysSeasonToDate",
    "DT00": "DaysMinTempLT0F",
    "AWND": "AverageWindSpeed",
    "CLDD": "CoolDegDays",
    "TAVG": "AverageTemp",
    "TMIN": "MinTemp",
    "TSUN": "TotalSunshinePeriod"})

# %%
dfClimate.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE',
#        'AverageWindSpeed', 'AWND_ATTRIBUTES', 'CoolDegDaysSeasonToDate',
#        'CDSD_ATTRIBUTES', 'CoolDegDays', 'CLDD_ATTRIBUTES',
#        'DaysWithGTTenthInchPrecip', 'DP01_ATTRIBUTES', 'DaysMoreThan1InchRain',
#        'DP10_ATTRIBUTES', 'DaysMinTempLT0F', 'DT00_ATTRIBUTES',
#        'DaysMinTempLT32F', 'DT32_ATTRIBUTES', 'DaysMaxTempLT32F',
#        'DX32_ATTRIBUTES', 'DaysMaxTempGT70F', 'DX70_ATTRIBUTES',
#        'DaysMaxTempGT90F', 'DX90_ATTRIBUTES', 'ExtremeMinTemp',
#        'EMNT_ATTRIBUTES', 'ExtremeMaxPrecip', 'EMXP_ATTRIBUTES',
#        'ExtremeMaxTemp', 'EMXT_ATTRIBUTES', 'HeatDegDaysSeasonToDate',
#        'HDSD_ATTRIBUTES', 'HeatDegDays', 'HTDD_ATTRIBUTES', 'Precipitation',
#        'PRCP_ATTRIBUTES', 'Snowfall', 'SNOW_ATTRIBUTES', 'AverageTemp',
#        'TAVG_ATTRIBUTES', 'MaxTemp', 'TMAX_ATTRIBUTES', 'MinTemp',
#        'TMIN_ATTRIBUTES', 'TotalSunshinePeriod', 'TSUN_ATTRIBUTES',
#        'DirFast2MinWind', 'WDF2_ATTRIBUTES', 'DirFast5MinWind',
#        'WDF5_ATTRIBUTES', 'SpeedFast2MinWind', 'WSF2_ATTRIBUTES',
#        'SpeedFast5MinWind', 'WSF5_ATTRIBUTES'],
#       dtype='object')

# %%
#Break Climate Data up to only show columns:AverageWindSpeed, Precipitation, Snowfall, AverageTemp and TotalSunshinePeriod, Ap, Cp
sub_columns = ['DATE', 'NAME', 'AverageWindSpeed','Precipitation','Snowfall','AverageTemp','TotalSunshinePeriod']
dfClimate = dfClimate[sub_columns]
dfClimate.head()
# Out:
#       DATE                          NAME  AverageWindSpeed  Precipitation  \
# 0  2000-01  LONDON CORBIN AIRPORT, KY US               6.7           3.27
# 1  2000-02  LONDON CORBIN AIRPORT, KY US               6.3           3.51
# 2  2000-03  LONDON CORBIN AIRPORT, KY US               5.8           2.54
# 3  2000-04  LONDON CORBIN AIRPORT, KY US               6.3           5.21
# 4  2000-05  LONDON CORBIN AIRPORT, KY US               5.6           3.10
#
#    Snowfall  AverageTemp  TotalSunshinePeriod
# 0       NaN         33.9                  NaN
# 1       NaN         43.0                  NaN
# 2       NaN         50.8                  NaN
# 3       NaN         54.0                  NaN
# 4       NaN         66.7                  NaN

# %%
#Need to look at the values of snowfall to see if they are all NaN, if so, it will not be a good variable 
dfClimate.Snowfall.unique()
# Out:
# array([nan])

# %%
#Also need to look at values of TotalSunshinePeriod to see if they are all NaN
dfClimate.TotalSunshinePeriod.unique()
# Out:
# array([nan,  0.])

# %%
#Remove snowfall and TotalSunshinePeriod from the subset 
del dfClimate['Snowfall']
del dfClimate['TotalSunshinePeriod']
dfClimate
# Out:
#          DATE                          NAME  AverageWindSpeed  Precipitation  \
# 0     2000-01  LONDON CORBIN AIRPORT, KY US               6.7           3.27
# 1     2000-02  LONDON CORBIN AIRPORT, KY US               6.3           3.51
# 2     2000-03  LONDON CORBIN AIRPORT, KY US               5.8           2.54
# 3     2000-04  LONDON CORBIN AIRPORT, KY US               6.3           5.21
# 4     2000-05  LONDON CORBIN AIRPORT, KY US               5.6           3.10
# ...       ...                           ...               ...            ...
# 1099  2019-08          ANNAPOLIS NAF, MD US               5.8           1.50
# 1100  2019-09          ANNAPOLIS NAF, MD US               6.5           0.25
# 1101  2019-10          ANNAPOLIS NAF, MD US               7.6           4.44
# 1102  2019-11          ANNAPOLIS NAF, MD US               6.9           0.73
# 1103  2019-12          ANNAPOLIS NAF, MD US               5.6           1.98
#
#       AverageTemp
# 0            33.9
# 1            43.0
# 2            50.8
# 3            54.0
# 4            66.7
# ...           ...
# 1099         80.7
# 1100         76.1
# 1101         62.4
# 1102         45.0
# 1103         40.7
#
# [1104 rows x 5 columns]

# %%
#Group climate data by date
dfClimate[['Year','Month']] = dfClimate['DATE'].str.split('-',expand=True)

# %%
del dfClimate['DATE']
dfClimate
# Out:
#                               NAME  AverageWindSpeed  Precipitation  \
# 0     LONDON CORBIN AIRPORT, KY US               6.7           3.27
# 1     LONDON CORBIN AIRPORT, KY US               6.3           3.51
# 2     LONDON CORBIN AIRPORT, KY US               5.8           2.54
# 3     LONDON CORBIN AIRPORT, KY US               6.3           5.21
# 4     LONDON CORBIN AIRPORT, KY US               5.6           3.10
# ...                            ...               ...            ...
# 1099          ANNAPOLIS NAF, MD US               5.8           1.50
# 1100          ANNAPOLIS NAF, MD US               6.5           0.25
# 1101          ANNAPOLIS NAF, MD US               7.6           4.44
# 1102          ANNAPOLIS NAF, MD US               6.9           0.73
# 1103          ANNAPOLIS NAF, MD US               5.6           1.98
#
#       AverageTemp  Year Month
# 0            33.9  2000    01
# 1            43.0  2000    02
# 2            50.8  2000    03
# 3            54.0  2000    04
# 4            66.7  2000    05
# ...           ...   ...   ...
# 1099         80.7  2019    08
# 1100         76.1  2019    09
# 1101         62.4  2019    10
# 1102         45.0  2019    11
# 1103         40.7  2019    12
#
# [1104 rows x 6 columns]

# %% [markdown]
# # Merge Data

# %%
dfClimate['Year'] = dfClimate.Year.astype('int64')
dfClimate['Month'] = dfClimate.Month.astype('int64')
dfClimate = pd.DataFrame(dfClimate.set_index(['Year', 'Month']))
dfClimate
# Out:
#                                     NAME  AverageWindSpeed  Precipitation  \
# Year Month
# 2000 1      LONDON CORBIN AIRPORT, KY US               6.7           3.27
#      2      LONDON CORBIN AIRPORT, KY US               6.3           3.51
#      3      LONDON CORBIN AIRPORT, KY US               5.8           2.54
#      4      LONDON CORBIN AIRPORT, KY US               6.3           5.21
#      5      LONDON CORBIN AIRPORT, KY US               5.6           3.10
# ...                                  ...               ...            ...
# 2019 8              ANNAPOLIS NAF, MD US               5.8           1.50
#      9              ANNAPOLIS NAF, MD US               6.5           0.25
#      10             ANNAPOLIS NAF, MD US               7.6           4.44
#      11             ANNAPOLIS NAF, MD US               6.9           0.73
#      12             ANNAPOLIS NAF, MD US               5.6           1.98
#
#             AverageTemp
# Year Month
# 2000 1             33.9
#      2             43.0
#      3             50.8
#      4             54.0
#      5             66.7
# ...                 ...
# 2019 8             80.7
#      9             76.1
#      10            62.4
#      11            45.0
#      12            40.7
#
# [1104 rows x 4 columns]

# %%
# Perform an inner join on the employees and departments data frames 
dfMergedData = pd.merge(spaceWeather_Averages, dfClimate, how = 'right', left_on=None, right_on=None, left_index=True, right_index=True)

# %%
dfFinal = dfMergedData.set_index('NAME',append=True)
dfFinal.head()
# Out:
#                                                        SumOfKps       F10_7  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US              187.645161  153.067742
#            JEROME CO AIRPORT, ID US                  187.645161  153.067742
#            SALINA MUNICIPAL AIRPORT, KS US           187.645161  153.067742
#            GREENVILLE MAINE FORESTRY SERVICE, ME US  187.645161  153.067742
#      2     LONDON CORBIN AIRPORT, KY US              205.689655  169.117241
#
#                                                      FluxQualifier  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                   0.064516
#            JEROME CO AIRPORT, ID US                       0.064516
#            SALINA MUNICIPAL AIRPORT, KS US                0.064516
#            GREENVILLE MAINE FORESTRY SERVICE, ME US       0.064516
#      2     LONDON CORBIN AIRPORT, KY US                   0.068966
#
#                                                      Centered81_dayArithmeticAverageofF10_7  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                                          162.309677
#            JEROME CO AIRPORT, ID US                                              162.309677
#            SALINA MUNICIPAL AIRPORT, KS US                                       162.309677
#            GREENVILLE MAINE FORESTRY SERVICE, ME US                              162.309677
#      2     LONDON CORBIN AIRPORT, KY US                                          175.689655
#
#                                                      Last81DayArithmeticAverageofF10_7  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                                     171.774194
#            JEROME CO AIRPORT, ID US                                         171.774194
#            SALINA MUNICIPAL AIRPORT, KS US                                  171.774194
#            GREENVILLE MAINE FORESTRY SERVICE, ME US                         171.774194
#      2     LONDON CORBIN AIRPORT, KY US                                     160.893103
#
#                                                      ObservedValueOfF10_7  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                        158.132258
#            JEROME CO AIRPORT, ID US                            158.132258
#            SALINA MUNICIPAL AIRPORT, KS US                     158.132258
#            GREENVILLE MAINE FORESTRY SERVICE, ME US            158.132258
#      2     LONDON CORBIN AIRPORT, KY US                        173.241379
#
#                                                      Centered81DayArithmeticAverageOfF10_7  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                                         167.190323
#            JEROME CO AIRPORT, ID US                                             167.190323
#            SALINA MUNICIPAL AIRPORT, KS US                                      167.190323
#            GREENVILLE MAINE FORESTRY SERVICE, ME US                             167.190323
#      2     LONDON CORBIN AIRPORT, KY US                                         179.472414
#
#                                                      Last81DayArithmeticAverageOfF10_7  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                                     176.454839
#            JEROME CO AIRPORT, ID US                                         176.454839
#            SALINA MUNICIPAL AIRPORT, KS US                                  176.454839
#            GREENVILLE MAINE FORESTRY SERVICE, ME US                         176.454839
#      2     LONDON CORBIN AIRPORT, KY US                                     165.889655
#
#                                                      ArithmeticAverageof8Ap  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                           12.967742
#            JEROME CO AIRPORT, ID US                               12.967742
#            SALINA MUNICIPAL AIRPORT, KS US                        12.967742
#            GREENVILLE MAINE FORESTRY SERVICE, ME US               12.967742
#      2     LONDON CORBIN AIRPORT, KY US                           15.413793
#
#                                                      PlanetaryDailyCharacterFigure  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                                   0.632258
#            JEROME CO AIRPORT, ID US                                       0.632258
#            SALINA MUNICIPAL AIRPORT, KS US                                0.632258
#            GREENVILLE MAINE FORESTRY SERVICE, ME US                       0.632258
#      2     LONDON CORBIN AIRPORT, KY US                                   0.720690
#
#                                                      InternationalSunspotNumber  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                               90.096774
#            JEROME CO AIRPORT, ID US                                   90.096774
#            SALINA MUNICIPAL AIRPORT, KS US                            90.096774
#            GREENVILLE MAINE FORESTRY SERVICE, ME US                   90.096774
#      2     LONDON CORBIN AIRPORT, KY US                              112.862069
#
#                                                      AverageWindSpeed  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                           6.7
#            JEROME CO AIRPORT, ID US                              11.2
#            SALINA MUNICIPAL AIRPORT, KS US                        8.7
#            GREENVILLE MAINE FORESTRY SERVICE, ME US              11.6
#      2     LONDON CORBIN AIRPORT, KY US                           6.3
#
#                                                      Precipitation  \
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                       3.27
#            JEROME CO AIRPORT, ID US                           2.10
#            SALINA MUNICIPAL AIRPORT, KS US                    0.27
#            GREENVILLE MAINE FORESTRY SERVICE, ME US           1.96
#      2     LONDON CORBIN AIRPORT, KY US                       3.51
#
#                                                      AverageTemp
# Year Month NAME
# 2000 1     LONDON CORBIN AIRPORT, KY US                     33.9
#            JEROME CO AIRPORT, ID US                         29.7
#            SALINA MUNICIPAL AIRPORT, KS US                  32.1
#            GREENVILLE MAINE FORESTRY SERVICE, ME US         14.0
#      2     LONDON CORBIN AIRPORT, KY US                     43.0

# %%
dfMergedSubsetLondon = dfMergedData[dfMergedData.NAME == 'LONDON CORBIN AIRPORT, KY US']
dfMergedSubsetLondon
# Out:
#               SumOfKps       F10_7  FluxQualifier  \
# Year Month
# 2000 1      187.645161  153.067742       0.064516
#      2      205.689655  169.117241       0.068966
#      3      145.322581  206.119355       0.000000
#      4      190.033333  185.490000       0.000000
#      5      196.741935  188.725806       0.064516
# ...                ...         ...            ...
# 2019 8      109.258065   68.661290       0.000000
#      9      151.633333   68.803333       0.000000
#      10     126.032258   67.009677       0.000000
#      11      79.333333   68.663333       0.000000
#      12      67.419355   70.593548      68.380645
#
#             Centered81_dayArithmeticAverageofF10_7  \
# Year Month
# 2000 1                                  162.309677
#      2                                  175.689655
#      3                                  187.287097
#      4                                  192.420000
#      5                                  186.835484
# ...                                            ...
# 2019 8                                   68.987097
#      9                                   68.200000
#      10                                  68.029032
#      11                                  68.796667
#      12                                  73.248387
#
#             Last81DayArithmeticAverageofF10_7  ObservedValueOfF10_7  \
# Year Month
# 2000 1                             171.774194            158.132258
#      2                             160.893103            173.241379
#      3                             170.693548            208.154839
#      4                             184.963333            184.163333
#      5                             191.977419            184.529032
# ...                                       ...                   ...
# 2019 8                              69.619355             66.974194
#      9                              69.096667             68.063333
#      10                             68.448387             67.429032
#      11                             68.026667             70.183333
#      12                             72.683871             69.506452
#
#             Centered81DayArithmeticAverageOfF10_7  \
# Year Month
# 2000 1                                 167.190323
#      2                                 179.472414
#      3                                 188.951613
#      4                                 191.240000
#      5                                 183.041935
# ...                                           ...
# 2019 8                                  67.429032
#      9                                  67.516667
#      10                                 68.416129
#      11                                 70.223333
#      12                                       NaN
#
#             Last81DayArithmeticAverageOfF10_7  ArithmeticAverageof8Ap  \
# Year Month
# 2000 1                             176.454839               12.967742
#      2                             165.889655               15.413793
#      3                             174.983871                8.870968
#      4                             187.373333               15.466667
#      5                             191.729032               15.161290
# ...                                       ...                     ...
# 2019 8                              67.535484                6.870968
#      9                              67.340000                9.833333
#      10                             67.464516                7.387097
#      11                             68.073333                4.200000
#      12                                   NaN                3.064516
#
#             PlanetaryDailyCharacterFigure  InternationalSunspotNumber  \
# Year Month
# 2000 1                           0.632258                   90.096774
#      2                           0.720690                  112.862069
#      3                           0.435484                  138.483871
#      4                           0.660000                  125.533333
#      5                           0.661290                  121.580645
# ...                                   ...                         ...
# 2019 8                           0.264516                    0.483871
#      9                           0.463333                    1.100000
#      10                          0.358065                    0.419355
#      11                          0.156667                    0.500000
#      12                          1.870968                    0.000000
#
#                                     NAME  AverageWindSpeed  Precipitation  \
# Year Month
# 2000 1      LONDON CORBIN AIRPORT, KY US               6.7           3.27
#      2      LONDON CORBIN AIRPORT, KY US               6.3           3.51
#      3      LONDON CORBIN AIRPORT, KY US               5.8           2.54
#      4      LONDON CORBIN AIRPORT, KY US               6.3           5.21
#      5      LONDON CORBIN AIRPORT, KY US               5.6           3.10
# ...                                  ...               ...            ...
# 2019 8      LONDON CORBIN AIRPORT, KY US               3.4           2.72
#      9      LONDON CORBIN AIRPORT, KY US               2.9           0.11
#      10     LONDON CORBIN AIRPORT, KY US               4.0           7.81
#      11     LONDON CORBIN AIRPORT, KY US               4.7           5.37
#      12     LONDON CORBIN AIRPORT, KY US               5.1           6.35
#
#             AverageTemp
# Year Month
# 2000 1             33.9
#      2             43.0
#      3             50.8
#      4             54.0
#      5             66.7
# ...                 ...
# 2019 8             75.7
#      9             74.9
#      10            60.1
#      11            42.3
#      12            43.6
#
# [240 rows x 15 columns]

# %%
df = pd.DataFrame(dfMergedSubsetLondon)
df
# Out:
#               SumOfKps       F10_7  FluxQualifier  \
# Year Month
# 2000 1      187.645161  153.067742       0.064516
#      2      205.689655  169.117241       0.068966
#      3      145.322581  206.119355       0.000000
#      4      190.033333  185.490000       0.000000
#      5      196.741935  188.725806       0.064516
# ...                ...         ...            ...
# 2019 8      109.258065   68.661290       0.000000
#      9      151.633333   68.803333       0.000000
#      10     126.032258   67.009677       0.000000
#      11      79.333333   68.663333       0.000000
#      12      67.419355   70.593548      68.380645
#
#             Centered81_dayArithmeticAverageofF10_7  \
# Year Month
# 2000 1                                  162.309677
#      2                                  175.689655
#      3                                  187.287097
#      4                                  192.420000
#      5                                  186.835484
# ...                                            ...
# 2019 8                                   68.987097
#      9                                   68.200000
#      10                                  68.029032
#      11                                  68.796667
#      12                                  73.248387
#
#             Last81DayArithmeticAverageofF10_7  ObservedValueOfF10_7  \
# Year Month
# 2000 1                             171.774194            158.132258
#      2                             160.893103            173.241379
#      3                             170.693548            208.154839
#      4                             184.963333            184.163333
#      5                             191.977419            184.529032
# ...                                       ...                   ...
# 2019 8                              69.619355             66.974194
#      9                              69.096667             68.063333
#      10                             68.448387             67.429032
#      11                             68.026667             70.183333
#      12                             72.683871             69.506452
#
#             Centered81DayArithmeticAverageOfF10_7  \
# Year Month
# 2000 1                                 167.190323
#      2                                 179.472414
#      3                                 188.951613
#      4                                 191.240000
#      5                                 183.041935
# ...                                           ...
# 2019 8                                  67.429032
#      9                                  67.516667
#      10                                 68.416129
#      11                                 70.223333
#      12                                       NaN
#
#             Last81DayArithmeticAverageOfF10_7  ArithmeticAverageof8Ap  \
# Year Month
# 2000 1                             176.454839               12.967742
#      2                             165.889655               15.413793
#      3                             174.983871                8.870968
#      4                             187.373333               15.466667
#      5                             191.729032               15.161290
# ...                                       ...                     ...
# 2019 8                              67.535484                6.870968
#      9                              67.340000                9.833333
#      10                             67.464516                7.387097
#      11                             68.073333                4.200000
#      12                                   NaN                3.064516
#
#             PlanetaryDailyCharacterFigure  InternationalSunspotNumber  \
# Year Month
# 2000 1                           0.632258                   90.096774
#      2                           0.720690                  112.862069
#      3                           0.435484                  138.483871
#      4                           0.660000                  125.533333
#      5                           0.661290                  121.580645
# ...                                   ...                         ...
# 2019 8                           0.264516                    0.483871
#      9                           0.463333                    1.100000
#      10                          0.358065                    0.419355
#      11                          0.156667                    0.500000
#      12                          1.870968                    0.000000
#
#                                     NAME  AverageWindSpeed  Precipitation  \
# Year Month
# 2000 1      LONDON CORBIN AIRPORT, KY US               6.7           3.27
#      2      LONDON CORBIN AIRPORT, KY US               6.3           3.51
#      3      LONDON CORBIN AIRPORT, KY US               5.8           2.54
#      4      LONDON CORBIN AIRPORT, KY US               6.3           5.21
#      5      LONDON CORBIN AIRPORT, KY US               5.6           3.10
# ...                                  ...               ...            ...
# 2019 8      LONDON CORBIN AIRPORT, KY US               3.4           2.72
#      9      LONDON CORBIN AIRPORT, KY US               2.9           0.11
#      10     LONDON CORBIN AIRPORT, KY US               4.0           7.81
#      11     LONDON CORBIN AIRPORT, KY US               4.7           5.37
#      12     LONDON CORBIN AIRPORT, KY US               5.1           6.35
#
#             AverageTemp
# Year Month
# 2000 1             33.9
#      2             43.0
#      3             50.8
#      4             54.0
#      5             66.7
# ...                 ...
# 2019 8             75.7
#      9             74.9
#      10            60.1
#      11            42.3
#      12            43.6
#
# [240 rows x 15 columns]

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Average Temperature

# %%
modelAvgTemp_Kp = smf.ols(formula = 'AverageTemp ~ SumOfKps', data = df)
resultsAvgTemp_Kp = modelAvgTemp_Kp.fit()
print(resultsAvgTemp_Kp.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            AverageTemp   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.059
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):              0.305
# Time:                        11:54:21   Log-Likelihood:                -985.81
# No. Observations:                 240   AIC:                             1976.
# Df Residuals:                     238   BIC:                             1983.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     53.7166      3.116     17.237      0.000      47.578      59.856
# SumOfKps       0.0214      0.021      1.029      0.305      -0.020       0.062
# ==============================================================================
# Omnibus:                      191.034   Durbin-Watson:                   0.348
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.045
# Skew:                          -0.148   Prob(JB):                     0.000199
# Kurtosis:                       1.728   Cond. No.                         491.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
fig, ax = plt.subplots()
ax = sns.regplot(x = resultsAvgTemp_Kp.fittedvalues, y=resultsAvgTemp_Kp.resid_pearson, fit_reg=False)
plt.show()

# %%
resid = resultsAvgTemp_Kp.resid_pearson.copy()
resid_std = stats.zscore(resid)
fig = statsmodels.graphics.gofplots.qqplot(resid, line='r')
plt.show()

# %%
fig, ax = plt.subplots()
ax = sns.distplot(resid_std)
plt.show()

# %% [markdown]
# ## Average Wind Speed

# %%
modelAvgWind_Kp = smf.ols(formula = 'AverageWindSpeed ~ SumOfKps', data = df)
resultsAvgWind_Kp = modelAvgWind_Kp.fit()
print(resultsAvgWind_Kp.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       AverageWindSpeed   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     2.098
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):              0.149
# Time:                        11:54:22   Log-Likelihood:                -385.12
# No. Observations:                 240   AIC:                             774.2
# Df Residuals:                     238   BIC:                             781.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.4791      0.255     17.560      0.000       3.977       4.982
# SumOfKps       0.0025      0.002      1.449      0.149      -0.001       0.006
# ==============================================================================
# Omnibus:                       48.259   Durbin-Watson:                   0.685
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               11.552
# Skew:                           0.167   Prob(JB):                      0.00310
# Kurtosis:                       1.978   Cond. No.                         491.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
fig, ax = plt.subplots()
ax = sns.regplot(x = resultsAvgWind_Kp.fittedvalues, y=resultsAvgWind_Kp.resid_pearson, fit_reg=False)
plt.show()

# %%
resid = resultsAvgWind_Kp.resid_pearson.copy()
resid_std = stats.zscore(resid)
fig = statsmodels.graphics.gofplots.qqplot(resid, line='r')
plt.show()

# %%
fig, ax = plt.subplots()
ax = sns.distplot(resid_std)
plt.show()

# %% [markdown]
# ## Precipitation

# %%
modelPrecip_Kp = smf.ols(formula = 'Precipitation ~ SumOfKps', data = df)
resultsPrecip_Kp = modelPrecip_Kp.fit()
print(resultsPrecip_Kp.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Precipitation   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.126
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):              0.290
# Time:                        11:54:23   Log-Likelihood:                -520.67
# No. Observations:                 240   AIC:                             1045.
# Df Residuals:                     238   BIC:                             1052.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.6481      0.449     10.359      0.000       3.764       5.532
# SumOfKps      -0.0032      0.003     -1.061      0.290      -0.009       0.003
# ==============================================================================
# Omnibus:                       25.091   Durbin-Watson:                   1.853
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.753
# Skew:                           0.755   Prob(JB):                     2.10e-07
# Kurtosis:                       3.890   Cond. No.                         491.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
fig, ax = plt.subplots()
ax = sns.regplot(x = resultsPrecip_Kp.fittedvalues, y=resultsPrecip_Kp.resid_pearson, fit_reg=False)
plt.show()

# %%
resid = resultsPrecip_Kp.resid_pearson.copy()
resid_std = stats.zscore(resid)
fig = statsmodels.graphics.gofplots.qqplot(resid, line='r')
plt.show()

# %%
fig, ax = plt.subplots()
ax = sns.distplot(resid_std)
plt.show()

# %% [markdown]
# # Random Forest Regression

# %% [markdown]
# ## Average Temperature

# %%
x = df.iloc[:,0:1].values
y = df.iloc[:, 14].values
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor.fit(x,y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
X_grid = np.arange(min(x), max(x), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 15
plt.rcParams["figure.figsize"] = fig_size
plt.scatter(x,y,color = 'blue')
plt.plot(X_grid, regressor.predict(X_grid), color = 'green')
plt.title('Random Forest Regression')
plt.xlabel('SumOfKps')
plt.ylabel('AverageTemp')
plt.show()

# %%
regressor300 = RandomForestRegressor(n_estimators = 300, random_state = 0)
regressor300.fit(x,y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=300, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
X_grid = np.arange(min(x), max(x), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 15
plt.rcParams["figure.figsize"] = fig_size
plt.scatter(x,y,color = 'blue')
plt.plot(X_grid, regressor300.predict(X_grid), color = 'green')
plt.title('Random Forest Regression')
plt.xlabel('SumOfKps')
plt.ylabel('AverageTemp')
plt.show()

# %% [markdown]
# ## Average Wind Speed

# %%
x2 = df.iloc[:,0:1].values
y2 = df.iloc[:, 12].values
regressor2 = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor2.fit(x,y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
X_grid2 = np.arange(min(x2), max(x2), 0.01)
X_grid2 = X_grid2.reshape((len(X_grid2), 1))
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 15
plt.rcParams["figure.figsize"] = fig_size
plt.scatter(x2,y2,color = 'blue')
plt.plot(X_grid2, regressor2.predict(X_grid2), color = 'green')
plt.title('Random Forest Regression')
plt.xlabel('SumOfKps')
plt.ylabel('AverageWindSpeed')
plt.show()

# %% [markdown]
# ## Precipitation

# %%
x3 = df.iloc[:,0:1].values
y3 = df.iloc[:, 13].values
regressor3 = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor3.fit(x,y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
X_grid3 = np.arange(min(x3), max(x3), 0.01)
X_grid3 = X_grid3.reshape((len(X_grid3), 1))
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 15
plt.rcParams["figure.figsize"] = fig_size
plt.scatter(x3,y3,color = 'blue')
plt.plot(X_grid3, regressor3.predict(X_grid3), color = 'green')
plt.title('Random Forest Regression')
plt.xlabel('SumOfKps')
plt.ylabel('AverageWindSpeed')
plt.show()

# %% [markdown]
# # Non Linear Regression

# %%
xm1 = np.array(df["SumOfKps"]) 
xm2 = np.array(df["F10_7"])
xm3 = np.array(df["InternationalSunspotNumber"])
ym = np.array(df["AverageTemp"])  # oil sales price received (outcome)

# calculate y
def calc_y(x):
    a = x[0]
    b = x[1]
    c = x[2]
    d = x[3]
    #y = a * xm1 + b  # linear regression
    y = a * ( xm1 ** b ) * ( xm2 ** c ) * ( xm3 ** d )
    return y

# define objective
def objective(x):
    # calculate y
    y = calc_y(x)
    # calculate objective
    obj = 0.0
    for i in range(len(ym)):
        obj = obj + ((y[i]-ym[i])/ym[i])**2    
    # return result
    return obj

# initial guesses
x0 = np.zeros(4)
x0[0] = 0.0 # a
x0[1] = 0.0 # b
x0[2] = 0.0 # c
x0[3] = 0.0 # d

# show initial objective
print('Initial Objective: ' + str(objective(x0)))

# optimize
# bounds on variables
my_bnds = (-100.0, 100.0)
bnds = (my_bnds, my_bnds, my_bnds, my_bnds)
solution = minimize(objective, x0, method='SLSQP', bounds=bnds)
x = solution.x
y = calc_y(x)

# show final objective
cObjective = 'Final Objective: ' + str(objective(x))
print(cObjective)

# print solution
print('Solution')

cA = 'A = ' + str(x[0])
print(cA)
cB = 'B = ' + str(x[1])
print(cB)
cC = 'C = ' + str(x[2])
print(cC)
cD = 'D = ' + str(x[3])
print(cD)

cFormula = "Formula is : " + "\n" \
           + "A * WTI^B * HH^C * PROPANE^D"
cLegend = cFormula + "\n" + cA + "\n" + cB + "\n" \
           + cC + "\n" + cD + "\n" + cObjective

#ym measured outcome
#y  predicted outcome

from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(ym,y)
r2 = r_value**2
cR2 = "R^2 correlation = " + str(r_value**2)
print(cR2)

# plot solution
plt.figure(1)
plt.title('Actual (YM) versus Predicted (Y) Outcomes For Non-Linear Regression')
plt.plot(ym,y,'o')
plt.xlabel('Measured Outcome (YM)')
plt.ylabel('Predicted Outcome (Y)')
plt.legend([cLegend])
plt.grid(True)
plt.show()
# Out:
# Initial Objective: 240.0
# Final Objective: 164.39081677019078
# Solution
# A = 9.13895034790039
# B = 0.0
# C = 0.0
# D = 0.0
# R^2 correlation = 0.0

# %%
# Transform Data
x = np.array(df["SumOfKps"])
poly = PolynomialFeatures(3, include_bias=False)
poly.fit_transform(x[:, None])
# Out:
# array([[1.87645161e+02, 3.52107066e+04, 6.60711871e+06],
#        [2.05689655e+02, 4.23082342e+04, 8.70236611e+06],
#        [1.45322581e+02, 2.11186524e+04, 3.06901707e+06],
#        [1.90033333e+02, 3.61126678e+04, 6.86261063e+06],
#        [1.96741935e+02, 3.87073892e+04, 7.61536666e+06],
#        [1.99866667e+02, 3.99466844e+04, 7.98401066e+06],
#        [2.10774194e+02, 4.44257607e+04, 9.36380388e+06],
#        [1.89354839e+02, 3.58552549e+04, 6.78936602e+06],
#        [2.10733333e+02, 4.44085378e+04, 9.35835919e+06],
#        [1.93935484e+02, 3.76109719e+04, 7.29410204e+06],
#        [1.98933333e+02, 3.95744711e+04, 7.87268145e+06],
#        [1.28612903e+02, 1.65412789e+04, 2.12742190e+06],
#        [1.39451613e+02, 1.94467523e+04, 2.71188098e+06],
#        [1.21071429e+02, 1.46582908e+04, 1.77470021e+06],
#        [1.94451613e+02, 3.78114298e+04, 7.35249350e+06],
#        [2.23066667e+02, 4.97587378e+04, 1.10995158e+07],
#        [1.52967742e+02, 2.33991301e+04, 3.57931209e+06],
#        [1.57032258e+02, 2.46591301e+04, 3.87227888e+06],
#        [1.55250000e+02, 2.41025625e+04, 3.74192283e+06],
#        [1.83129032e+02, 3.35362425e+04, 6.14145963e+06],
#        [1.68366667e+02, 2.83473344e+04, 4.77274621e+06],
#        [1.25709677e+02, 1.58029230e+04, 1.98658035e+06],
#        [1.07333333e+02, 1.15204444e+04, 1.23652770e+06],
#        [1.33096774e+02, 1.77147513e+04, 2.35777625e+06],
#        [1.58000000e+02, 2.49640000e+04, 3.94431200e+06],
#        [2.05133333e+02, 4.20796844e+04, 8.63194594e+06],
#        [1.46580645e+02, 2.14858855e+04, 3.14941496e+06],
#        [1.49000000e+02, 2.22010000e+04, 3.30794900e+06],
#        [1.21645161e+02, 1.47975453e+04, 1.80004978e+06],
#        [1.00580645e+02, 1.01164662e+04, 1.01752070e+06],
#        [1.08535714e+02, 1.17800013e+04, 1.27855085e+06],
#        [1.30096774e+02, 1.69251707e+04, 2.20191010e+06],
#        [1.11433333e+02, 1.24173878e+04, 1.38371091e+06],
#        [1.14225806e+02, 1.30475349e+04, 1.49036519e+06],
#        [1.13433333e+02, 1.28671211e+04, 1.45956044e+06],
#        [9.77419355e+01, 9.55348595e+03, 9.33776208e+05],
#        [1.33032258e+02, 1.76975817e+04, 2.35434925e+06],
#        [1.42900000e+02, 2.04204100e+04, 2.91807659e+06],
#        [1.07612903e+02, 1.15805369e+04, 1.24621520e+06],
#        [9.09666667e+01, 8.27493444e+03, 7.52743203e+05],
#        [1.12612903e+02, 1.26816660e+04, 1.42811922e+06],
#        [1.02129032e+02, 1.04303392e+04, 1.06524045e+06],
#        [1.17142857e+02, 1.37224490e+04, 1.60748688e+06],
#        [1.08000000e+02, 1.16640000e+04, 1.25971200e+06],
#        [1.14966667e+02, 1.32173344e+04, 1.51955288e+06],
#        [1.16032258e+02, 1.34634849e+04, 1.56219856e+06],
#        [7.52333333e+01, 5.66005444e+03, 4.25824763e+05],
#        [9.85483871e+01, 9.71178460e+03, 9.57080708e+05],
#        [1.09258065e+02, 1.19373247e+04, 1.30424899e+06],
#        [1.51633333e+02, 2.29926678e+04, 3.48645486e+06],
#        [1.26032258e+02, 1.58841301e+04, 2.00191278e+06],
#        [7.93333333e+01, 6.29377778e+03, 4.99306370e+05],
#        [6.74193548e+01, 4.54536941e+03, 3.06445873e+05]])

# %%
poly_model = make_pipeline(PolynomialFeatures(7),LinearRegression)

# %%
rng = np.random.RandomState(1)
x = 10*rng.rand(50)
y = np.sin(x) + 0.1 * rng.randn(50)
x = x[:, np.newaxis]
poly_model.fit(x,y)
yfit = poly_model.predict(xfit[:, np.newaxis])
plt.scatter(x,y)
plt.plot(xfit, yfit)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-586cb75762c7> in <module>
#       3 y = np.sin(x) + 0.1 * rng.randn(50)
#       4 x = x[:, np.newaxis]
# ----> 5 poly_model.fit(x, x,y)
#       6 yfit = poly_model.predict(xfit[:, np.newaxis])
#       7 plt.scatter(x,y)
#
# TypeError: fit() takes from 2 to 3 positional arguments but 4 were given
